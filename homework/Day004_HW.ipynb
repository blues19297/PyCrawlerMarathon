# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
# r.text
import requests
r = requests.get('https://api.github.com/events')
print(r.text)

# json.loads(r.text)
import json
json.loads(r.text)
# Out:
# [{"id":"12889015471","type":"CreateEvent","actor":{"id":2211529,"login":"mrtonyhuynh","display_login":"mrtonyhuynh","gravatar_id":"","url":"https://api.github.com/users/mrtonyhuynh","avatar_url":"https://avatars.githubusercontent.com/u/2211529?"},"repo":{"id":279316931,"name":"mrtonyhuynh/docker-phpfpm-7.4","url":"https://api.github.com/repos/mrtonyhuynh/docker-phpfpm-7.4"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-07-13T13:54:54Z"},{"id":"12889015454","type":"ForkEvent","actor":{"id":31299270,"login":"hayato-kamata","display_login":"hayato-kamata","gravatar_id":"","url":"https://api.github.com/users/hayato-kamata","avatar_url":"https://avatars.githubusercontent.com/u/31299270?"},"repo":{"id":123932375,"name":"basler/pypylon","url":"https://api.github.com/repos/basler/pypylon"},"payload":{"forkee":{"id":279316935,"node_id":"MDEwOlJlcG9zaXRvcnkyNzkzMTY5MzU=","name":"pypylon","full_name":"hayato-kamata/pypylon","private":false,"owner":{"login":"hayato-kamata","id":31299270,"node_id":"MDQ6VXNlcjMxMjk5Mjcw","avatar_url":"https://avatars0.githubusercontent.com/u/31299270?v=4","gravatar_id":"","url":"https://api.github.com/users/hayato-kamata","html_url":"https://github.com/hayato-kamata","followers_url":"https://api.github.com/users/hayato-kamata/followers","following_url":"https://api.github.com/users/hayato-kamata/following{/other_user}","gists_url":"https://api.github.com/users/hayato-kamata/gists{/gist_id}","starred_url":"https://api.github.com/users/hayato-kamata/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/hayato-kamata/subscriptions","organizations_url":"https://api.github.com/users/hayato-kamata/orgs","repos_url":"https://api.github.com/users/hayato-kamata/repos","events_url":"https://api.github.com/users/hayato-kamata/events{/privacy}","received_events_url":"https://api.github.com/users/hayato-kamata/received_events","type":"User","site_admin":false},"html_url":"https://github.com/hayato-kamata/pypylon","description":"The official python wrapper for the pylon Camera Software Suite","fork":true,"url":"https://api.github.com/repos/hayato-kamata/pypylon","forks_url":"https://api.github.com/repos/hayato-kamata/pypylon/forks","keys_url":"https://api.github.com/repos/hayato-kamata/pypylon/keys{/key_id}","collaborators_url":"https://api.github.com/repos/hayato-kamata/pypylon/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/hayato-kamata/pypylon/teams","hooks_url":"https://api.github.com/repos/hayato-kamata/pypylon/hooks","issue_events_url":"https://api.github.com/repos/hayato-kamata/pypylon/issues/events{/number}","events_url":"https://api.github.com/repos/hayato-kamata/pypylon/events","assignees_url":"https://api.github.com/repos/hayato-kamata/pypylon/assignees{/user}","branches_url":"https://api.github.com/repos/hayato-kamata/pypylon/branches{/branch}","tags_url":"https://api.github.com/repos/hayato-kamata/pypylon/tags","blobs_url":"https://api.github.com/repos/hayato-kamata/pypylon/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/hayato-kamata/pypylon/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/hayato-kamata/pypylon/git/refs{/sha}","trees_url":"https://api.github.com/repos/hayato-kamata/pypylon/git/trees{/sha}","statuses_url":"https://api.github.com/repos/hayato-kamata/pypylon/statuses/{sha}","languages_url":"https://api.github.com/repos/hayato-kamata/pypylon/languages","stargazers_url":"https://api.github.com/repos/hayato-kamata/pypylon/stargazers","contributors_url":"https://api.github.com/repos/hayato-kamata/pypylon/contributors","subscribers_url":"https://api.github.com/repos/hayato-kamata/pypylon/subscribers","subscription_url":"https://api.github.com/repos/hayato-kamata/pypylon/subscription","commits_url":"https://api.github.com/repos/hayato-kamata/pypylon/commits{/sha}","git_commits_url":"https://api.github.com/repos/hayato-kamata/pypylon ...
# [{'id': '12889015471',
#   'type': 'CreateEvent',
#   'actor': {'id': 2211529,
#    'login': 'mrtonyhuynh',
#    'display_login': 'mrtonyhuynh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mrtonyhuynh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2211529?'},
#   'repo': {'id': 279316931,
#    'name': 'mrtonyhuynh/docker-phpfpm-7.4',
#    'url': 'https://api.github.com/repos/mrtonyhuynh/docker-phpfpm-7.4'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015454',
#   'type': 'ForkEvent',
#   'actor': {'id': 31299270,
#    'login': 'hayato-kamata',
#    'display_login': 'hayato-kamata',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hayato-kamata',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31299270?'},
#   'repo': {'id': 123932375,
#    'name': 'basler/pypylon',
#    'url': 'https://api.github.com/repos/basler/pypylon'},
#   'payload': {'forkee': {'id': 279316935,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNzkzMTY5MzU=',
#     'name': 'pypylon',
#     'full_name': 'hayato-kamata/pypylon',
#     'private': False,
#     'owner': {'login': 'hayato-kamata',
#      'id': 31299270,
#      'node_id': 'MDQ6VXNlcjMxMjk5Mjcw',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/31299270?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/hayato-kamata',
#      'html_url': 'https://github.com/hayato-kamata',
#      'followers_url': 'https://api.github.com/users/hayato-kamata/followers',
#      'following_url': 'https://api.github.com/users/hayato-kamata/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hayato-kamata/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/hayato-kamata/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hayato-kamata/subscriptions',
#      'organizations_url': 'https://api.github.com/users/hayato-kamata/orgs',
#      'repos_url': 'https://api.github.com/users/hayato-kamata/repos',
#      'events_url': 'https://api.github.com/users/hayato-kamata/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/hayato-kamata/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/hayato-kamata/pypylon',
#     'description': 'The official python wrapper for the pylon Camera Software Suite',
#     'fork': True,
#     'url': 'https://api.github.com/repos/hayato-kamata/pypylon',
#     'forks_url': 'https://api.github.com/repos/hayato-kamata/pypylon/forks',
#     'keys_url': 'https://api.github.com/repos/hayato-kamata/pypylon/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/hayato-kamata/pypylon/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/hayato-kamata/pypylon/teams',
#     'hooks_url': 'https://api.github.com/repos/hayato-kamata/pypylon/hooks',
#     'issue_events_url': 'https://api.github.com/repos/hayato-kamata/pypylon/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/hayato-kamata/pypylon/events',
#     'assignees_url': 'https://api.github.com/repos/hayato-kamata/pypylon/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/hayato-kamata/pypylon/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/hayato-kamata/pypylon/tags',
#     'blobs_url': 'https://api.github.com/repos/hayato-kamata/pypylon/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/hayato-kamata/pypylon/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/hayato-kamata/pypylon/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/hayato-kamata/pypylon/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/hayato-kamata/pypylon/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/hayato-kamata/pypylon/languages',
#     'stargazers_url': 'https://api.github.com/repos/hayato-kamata/pypylon/stargazers',
#     'contributors_url': 'https://api.github.com/repos/hayato-kamata/pypylon/contributors',
#     'subscribers_url': 'https://api.github.com/repos/hayato-kamata/pypylon/subscribers',
#     'subscription_url': 'https://api.github.com/repos/hayato-kamata/pypylon/subscription',
#     'commits_url': 'https://api.github.com/repos/hayato-kamata/pypylon/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/hayato-kamata/pypylon/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/hayato-kamata/pypylon/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/hayato-kamata/pypylon/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/hayato-kamata/pypylon/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/hayato-kamata/pypylon/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/hayato-kamata/pypylon/merges',
#     'archive_url': 'https://api.github.com/repos/hayato-kamata/pypylon/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/hayato-kamata/pypylon/downloads',
#     'issues_url': 'https://api.github.com/repos/hayato-kamata/pypylon/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/hayato-kamata/pypylon/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/hayato-kamata/pypylon/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/hayato-kamata/pypylon/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/hayato-kamata/pypylon/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/hayato-kamata/pypylon/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/hayato-kamata/pypylon/deployments',
#     'created_at': '2020-07-13T13:54:54Z',
#     'updated_at': '2020-07-11T02:36:49Z',
#     'pushed_at': '2020-06-26T09:15:07Z',
#     'git_url': 'git://github.com/hayato-kamata/pypylon.git',
#     'ssh_url': 'git@github.com:hayato-kamata/pypylon.git',
#     'clone_url': 'https://github.com/hayato-kamata/pypylon.git',
#     'svn_url': 'https://github.com/hayato-kamata/pypylon',
#     'homepage': 'http://www.baslerweb.com',
#     'size': 379,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'bsd-3-clause',
#      'name': 'BSD 3-Clause "New" or "Revised" License',
#      'spdx_id': 'BSD-3-Clause',
#      'url': 'https://api.github.com/licenses/bsd-3-clause',
#      'node_id': 'MDc6TGljZW5zZTU='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z',
#   'org': {'id': 10543739,
#    'login': 'basler',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/basler',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10543739?'}},
#  {'id': '12889015453',
#   'type': 'PushEvent',
#   'actor': {'id': 50553530,
#    'login': 'xiaowuc2',
#    'display_login': 'xiaowuc2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xiaowuc2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50553530?'},
#   'repo': {'id': 266003475,
#    'name': 'xiaowuc2/30-Days-of-Coding',
#    'url': 'https://api.github.com/repos/xiaowuc2/30-Days-of-Coding'},
#   'payload': {'push_id': 5366082214,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '40a6499889d6f0fd533cc66ff0caa03cf5a737a4',
#    'before': '3f8d049b222c9d48b237e3931e562b0767e536bf',
#    'commits': [{'sha': '40a6499889d6f0fd533cc66ff0caa03cf5a737a4',
#      'author': {'email': '50553530+xiaowuc2@users.noreply.github.com',
#       'name': 'Rohit Prasan Mandal'},
#      'message': 'Update Solution.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xiaowuc2/30-Days-of-Coding/commits/40a6499889d6f0fd533cc66ff0caa03cf5a737a4'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015451',
#   'type': 'CreateEvent',
#   'actor': {'id': 68122123,
#    'login': 'anioloads1',
#    'display_login': 'anioloads1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anioloads1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68122123?'},
#   'repo': {'id': 279316933,
#    'name': 'anioloads1/43030',
#    'url': 'https://api.github.com/repos/anioloads1/43030'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015447',
#   'type': 'WatchEvent',
#   'actor': {'id': 66082085,
#    'login': 'chinmaykarmokar',
#    'display_login': 'chinmaykarmokar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chinmaykarmokar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66082085?'},
#   'repo': {'id': 272400318,
#    'name': 'GitGuardian/gg-shield-action',
#    'url': 'https://api.github.com/repos/GitGuardian/gg-shield-action'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z',
#   'org': {'id': 27360172,
#    'login': 'GitGuardian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/GitGuardian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27360172?'}},
#  {'id': '12889015449',
#   'type': 'WatchEvent',
#   'actor': {'id': 782753,
#    'login': 'snum',
#    'display_login': 'snum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/snum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/782753?'},
#   'repo': {'id': 71056775,
#    'name': 'kovidgoyal/kitty',
#    'url': 'https://api.github.com/repos/kovidgoyal/kitty'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015440',
#   'type': 'PushEvent',
#   'actor': {'id': 68224228,
#    'login': 'rheimers',
#    'display_login': 'rheimers',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rheimers',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68224228?'},
#   'repo': {'id': 279308898,
#    'name': 'rheimers/markdown-portfolio',
#    'url': 'https://api.github.com/repos/rheimers/markdown-portfolio'},
#   'payload': {'push_id': 5366082208,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/add-images-links',
#    'head': '9992a053d9ac064a4eaaee80b7c839c073a3cb2e',
#    'before': 'ca7c3b45dcc850e6f0feaebe0be61e789236f43e',
#    'commits': [{'sha': '9992a053d9ac064a4eaaee80b7c839c073a3cb2e',
#      'author': {'email': '68224228+rheimers@users.noreply.github.com',
#       'name': 'rheimers'},
#      'message': 'Update 02-image.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rheimers/markdown-portfolio/commits/9992a053d9ac064a4eaaee80b7c839c073a3cb2e'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015438',
#   'type': 'IssuesEvent',
#   'actor': {'id': 58094558,
#    'login': 'pddemo',
#    'display_login': 'pddemo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pddemo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58094558?'},
#   'repo': {'id': 277422872,
#    'name': 'pddemo/demo',
#    'url': 'https://api.github.com/repos/pddemo/demo'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/pddemo/demo/issues/10676',
#     'repository_url': 'https://api.github.com/repos/pddemo/demo',
#     'labels_url': 'https://api.github.com/repos/pddemo/demo/issues/10676/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/pddemo/demo/issues/10676/comments',
#     'events_url': 'https://api.github.com/repos/pddemo/demo/issues/10676/events',
#     'html_url': 'https://github.com/pddemo/demo/issues/10676',
#     'id': 655872344,
#     'node_id': 'MDU6SXNzdWU2NTU4NzIzNDQ=',
#     'number': 10676,
#     'title': 'Rustic Cotton Soap',
#     'user': {'login': 'pddemo',
#      'id': 58094558,
#      'node_id': 'MDQ6VXNlcjU4MDk0NTU4',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/58094558?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pddemo',
#      'html_url': 'https://github.com/pddemo',
#      'followers_url': 'https://api.github.com/users/pddemo/followers',
#      'following_url': 'https://api.github.com/users/pddemo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pddemo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pddemo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pddemo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pddemo/orgs',
#      'repos_url': 'https://api.github.com/users/pddemo/repos',
#      'events_url': 'https://api.github.com/users/pddemo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pddemo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-07-13T13:54:54Z',
#     'updated_at': '2020-07-13T13:54:54Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': None}},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015433',
#   'type': 'WatchEvent',
#   'actor': {'id': 168856,
#    'login': 'orenyomtov',
#    'display_login': 'orenyomtov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/orenyomtov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/168856?'},
#   'repo': {'id': 151871286,
#    'name': 'pipxproject/pipx',
#    'url': 'https://api.github.com/repos/pipxproject/pipx'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z',
#   'org': {'id': 47152844,
#    'login': 'pipxproject',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pipxproject',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47152844?'}},
#  {'id': '12889015434',
#   'type': 'CreateEvent',
#   'actor': {'id': 7571158,
#    'login': 'xmo-odoo',
#    'display_login': 'xmo-odoo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xmo-odoo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7571158?'},
#   'repo': {'id': 279316910,
#    'name': 'odoo-mergebot-testing-org/ignore_repo_-DeA1jId',
#    'url': 'https://api.github.com/repos/odoo-mergebot-testing-org/ignore_repo_-DeA1jId'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'garbage_9ce356c5-8eeb-45a8-8de4-ece2ee6480b3',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z',
#   'org': {'id': 39950501,
#    'login': 'odoo-mergebot-testing-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/odoo-mergebot-testing-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39950501?'}},
#  {'id': '12889015393',
#   'type': 'PushEvent',
#   'actor': {'id': 16837285,
#    'login': 'robodoo',
#    'display_login': 'robodoo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/robodoo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16837285?'},
#   'repo': {'id': 19745004,
#    'name': 'odoo/odoo',
#    'url': 'https://api.github.com/repos/odoo/odoo'},
#   'payload': {'push_id': 5366082152,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/tmp.saas-13.4',
#    'head': '6b7a2589275a4633c2ad223b0cfc36a4857b58d6',
#    'before': '4ff8e59315d67236938728a785efe1f1f890906b',
#    'commits': [{'sha': 'f447425c9bd891f7206b97ea7c6475fd056df9d2',
#      'author': {'email': 'agr@odoo.com', 'name': 'Andrea Grazioso (agr-odoo)'},
#      'message': '[FIX] website_sale: form data lost when applying coupon\n\nGo to eshop with public user\nAdd items in cart\nCheckout, reach shipping and billing address page\nFill the form\nAdd a coupon\n\nPage will refresh and added content will be lost\nThis will prevent user from adding a coupon when a form needs to be\nfilled\n\nopw-2287428\n\nX-original-commit: 4ed42845624e39c66222cda81f307236a6d5a483',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/odoo/odoo/commits/f447425c9bd891f7206b97ea7c6475fd056df9d2'},
#     {'sha': '6b7a2589275a4633c2ad223b0cfc36a4857b58d6',
#      'author': {'email': 'robodoo@odoo.com', 'name': "Odoo's Mergebot"},
#      'message': 'temp rebasing PR 54390 (f447425c9bd891f7206b97ea7c6475fd056df9d2)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/odoo/odoo/commits/6b7a2589275a4633c2ad223b0cfc36a4857b58d6'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z',
#   'org': {'id': 6368483,
#    'login': 'odoo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/odoo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6368483?'}},
#  {'id': '12889015412',
#   'type': 'PushEvent',
#   'actor': {'id': 58159203,
#    'login': 'thanakrit-sa',
#    'display_login': 'thanakrit-sa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thanakrit-sa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58159203?'},
#   'repo': {'id': 261082730,
#    'name': 'thanakrit-sa/Backup_LIFF',
#    'url': 'https://api.github.com/repos/thanakrit-sa/Backup_LIFF'},
#   'payload': {'push_id': 5366082190,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c1238f2585c98e017ef56152486fab197d89dca0',
#    'before': 'bfca98a65945a8dcb719c72ccf479d4d6d5ce518',
#    'commits': [{'sha': 'c1238f2585c98e017ef56152486fab197d89dca0',
#      'author': {'email': 'thanakrit.10197@gmail.com',
#       'name': 'Thanakrit Sahachatchai'},
#      'message': 'now',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/thanakrit-sa/Backup_LIFF/commits/c1238f2585c98e017ef56152486fab197d89dca0'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015409',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 268002479,
#    'name': 'jmcdo29/nestjs-throttler',
#    'url': 'https://api.github.com/repos/jmcdo29/nestjs-throttler'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/apollo-server-express-2.15.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A rate limiting module for NestJS to work with Fastify, Express, GQL, Websockets, and RPC',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015406',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 15837671,
#    'login': 'elasticmachine',
#    'display_login': 'elasticmachine',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elasticmachine',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15837671?'},
#   'repo': {'id': 16554739,
#    'name': 'elastic/beats',
#    'url': 'https://api.github.com/repos/elastic/beats'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/elastic/beats/issues/19712',
#     'repository_url': 'https://api.github.com/repos/elastic/beats',
#     'labels_url': 'https://api.github.com/repos/elastic/beats/issues/19712/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/elastic/beats/issues/19712/comments',
#     'events_url': 'https://api.github.com/repos/elastic/beats/issues/19712/events',
#     'html_url': 'https://github.com/elastic/beats/issues/19712',
#     'id': 652462561,
#     'node_id': 'MDU6SXNzdWU2NTI0NjI1NjE=',
#     'number': 19712,
#     'title': './filebeat generate fields with pipeline.yml',
#     'user': {'login': 'Bernhard-Fluehmann',
#      'id': 59565936,
#      'node_id': 'MDQ6VXNlcjU5NTY1OTM2',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/59565936?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Bernhard-Fluehmann',
#      'html_url': 'https://github.com/Bernhard-Fluehmann',
#      'followers_url': 'https://api.github.com/users/Bernhard-Fluehmann/followers',
#      'following_url': 'https://api.github.com/users/Bernhard-Fluehmann/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Bernhard-Fluehmann/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Bernhard-Fluehmann/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Bernhard-Fluehmann/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Bernhard-Fluehmann/orgs',
#      'repos_url': 'https://api.github.com/users/Bernhard-Fluehmann/repos',
#      'events_url': 'https://api.github.com/users/Bernhard-Fluehmann/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Bernhard-Fluehmann/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1096959716,
#       'node_id': 'MDU6TGFiZWwxMDk2OTU5NzE2',
#       'url': 'https://api.github.com/repos/elastic/beats/labels/Team:SIEM',
#       'name': 'Team:SIEM',
#       'color': '1d76db',
#       'default': False,
#       'description': 'SIEM team issues/PRs'},
#      {'id': 1810687793,
#       'node_id': 'MDU6TGFiZWwxODEwNjg3Nzkz',
#       'url': 'https://api.github.com/repos/elastic/beats/labels/Team:Services',
#       'name': 'Team:Services',
#       'color': 'fbca04',
#       'default': False,
#       'description': 'Integrations - Services issues/PRs'},
#      {'id': 1135206081,
#       'node_id': 'MDU6TGFiZWwxMTM1MjA2MDgx',
#       'url': 'https://api.github.com/repos/elastic/beats/labels/[zube]:%20Inbox',
#       'name': '[zube]: Inbox',
#       'color': 'ffffff',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-07-07T16:34:41Z',
#     'updated_at': '2020-07-13T13:54:54Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'Hey, stop right there!\r\n\r\nHi, I have opened a [discussion](https://discuss.elastic.co/t/filebeat-generate-fields-with-pipeline-yml/239790) and was told to open an issue for this topic.\r\n\r\n**This is the text of the original request:**\r\nI am developing a new filebeat module for sophos firewall logs. Now I got stuck on\r\nthe ./filebeat generate fields command. It returns with the following error:\r\n\r\ncannot read pipeline: open module/sophos/secureweb/ingest/pipeline.json: no such file or directory\r\n\r\nThis makes sense since my pipeline is called pipeline.yml. It is configured like this in the manifest file of the fileset. I have though already to convert the file back to json but since almost all pipelines of the existing modules are in yml I wonder what I am doing wrong.\r\n\r\nIt was mentioned that the field creation script only supports json pipelines. and I should request adding yml support.\r\n\r\nOne other strange thing I observed when I was testing the script with a json pipeline was that it seems just to create fields parsed with grok. All other fields created with set and rename processors, were ignored.\r\nGiven that observation and the fact that almost all module pipelines are yml files let me wonder if the script is still needed at all or if there are other tools or manual processes in use to create fields.\r\n\r\nAnd as a last question, let me ask the best practice to create pipelines. The manual proposes to use devtools (json pipeline) with simulate api. This is what I am doing so far. But this means at all module pipelines are in yml, the developed pipelines need to be converted somehow to yml. Is there a way to simulate yml pipelines directly, either by elasticsearch accepting yml pipelienes or with a simulate script in filebeat?\r\n\r\nI am looking forward for your answers, since I have a couple of use cases to process new log types\r\n\r\nRegards\r\nBernhard\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/elastic/beats/issues/comments/657575675',
#     'html_url': 'https://github.com/elastic/beats/issues/19712#issuecomment-657575675',
#     'issue_url': 'https://api.github.com/repos/elastic/beats/issues/19712',
#     'id': 657575675,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY1NzU3NTY3NQ==',
#     'user': {'login': 'elasticmachine',
#      'id': 15837671,
#      'node_id': 'MDQ6VXNlcjE1ODM3Njcx',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/15837671?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/elasticmachine',
#      'html_url': 'https://github.com/elasticmachine',
#      'followers_url': 'https://api.github.com/users/elasticmachine/followers',
#      'following_url': 'https://api.github.com/users/elasticmachine/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/elasticmachine/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/elasticmachine/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/elasticmachine/subscriptions',
#      'organizations_url': 'https://api.github.com/users/elasticmachine/orgs',
#      'repos_url': 'https://api.github.com/users/elasticmachine/repos',
#      'events_url': 'https://api.github.com/users/elasticmachine/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/elasticmachine/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-07-13T13:54:54Z',
#     'updated_at': '2020-07-13T13:54:54Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'Pinging @elastic/siem (Team:SIEM)'}},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z',
#   'org': {'id': 6764390,
#    'login': 'elastic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/elastic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6764390?'}},
#  {'id': '12889015402',
#   'type': 'CreateEvent',
#   'actor': {'id': 6749661,
#    'login': 'test987987',
#    'display_login': 'test987987',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/test987987',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6749661?'},
#   'repo': {'id': 40834904,
#    'name': 'test987987/test12',
#    'url': 'https://api.github.com/repos/test987987/test12'},
#   'payload': {'ref': '3ed55143-4edf-4b81-a5ea-0dbc12109aeb',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015382',
#   'type': 'PushEvent',
#   'actor': {'id': 26408,
#    'login': 'tafsiri',
#    'display_login': 'tafsiri',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tafsiri',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26408?'},
#   'repo': {'id': 123870315,
#    'name': 'tensorflow/tfjs',
#    'url': 'https://api.github.com/repos/tensorflow/tfjs'},
#   'payload': {'push_id': 5366082169,
#    'size': 4,
#    'distinct_size': 2,
#    'ref': 'refs/heads/mod-unary-3',
#    'head': 'e8da6d7b68466358ff58e3a7bddcced7ac0d0d30',
#    'before': '8aac335f79ee66a303ec51c37913addfa74a1de8',
#    'commits': [{'sha': 'f2ac49c777c398a58c6976be98dff65ee24a1765',
#      'author': {'email': '40653845+Linchenn@users.noreply.github.com',
#       'name': 'Linchenn'},
#      'message': 'Add unit test configuration for benchmark tools (#3583)\n\nFEATURE',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/tensorflow/tfjs/commits/f2ac49c777c398a58c6976be98dff65ee24a1765'},
#     {'sha': '675a5471a2d1e53666b1cfd79d1e650dc86d3852',
#      'author': {'email': '40653845+Linchenn@users.noreply.github.com',
#       'name': 'Linchenn'},
#      'message': 'Extract profileInferenceMemory from the benchmark webpage (#3565)\n\nBREAKING profile inference memory',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/tensorflow/tfjs/commits/675a5471a2d1e53666b1cfd79d1e650dc86d3852'},
#     {'sha': 'd6b5409b9d54af5bd7da3458fb7c85054b98dfe9',
#      'author': {'email': 'yassogba@google.com', 'name': 'Yannick Assogba'},
#      'message': "Merge branch 'master' into mod-unary-3",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tensorflow/tfjs/commits/d6b5409b9d54af5bd7da3458fb7c85054b98dfe9'},
#     {'sha': 'e8da6d7b68466358ff58e3a7bddcced7ac0d0d30',
#      'author': {'email': 'yassogba@google.com', 'name': 'Yannick Assogba'},
#      'message': 'code review fixes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tensorflow/tfjs/commits/e8da6d7b68466358ff58e3a7bddcced7ac0d0d30'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z',
#   'org': {'id': 15658638,
#    'login': 'tensorflow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tensorflow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15658638?'}},
#  {'id': '12889015395',
#   'type': 'PushEvent',
#   'actor': {'id': 8311311,
#    'login': 'luksab',
#    'display_login': 'luksab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/luksab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8311311?'},
#   'repo': {'id': 269359524,
#    'name': 'luksab/HiRISE',
#    'url': 'https://api.github.com/repos/luksab/HiRISE'},
#   'payload': {'push_id': 5366082172,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8a784fd46ccab94919b796f2f1a5ccbc9c8a43d3',
#    'before': 'd8b66098ae570c7579f26dfc2f520942d28c2e03',
#    'commits': [{'sha': '8a784fd46ccab94919b796f2f1a5ccbc9c8a43d3',
#      'author': {'email': 'luksablp@gmail.com', 'name': 'luksab'},
#      'message': 'create Blender bxport html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/luksab/HiRISE/commits/8a784fd46ccab94919b796f2f1a5ccbc9c8a43d3'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015397',
#   'type': 'CreateEvent',
#   'actor': {'id': 67893692,
#    'login': 'eugen-mueller',
#    'display_login': 'eugen-mueller',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eugen-mueller',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67893692?'},
#   'repo': {'id': 279306100,
#    'name': 'eugen-mueller/sdk',
#    'url': 'https://api.github.com/repos/eugen-mueller/sdk'},
#   'payload': {'ref': 'new_branch',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'The Geotab SDK (Software Development Kit) is a powerful set of tools for automating tasks and working with the data in MyGeotab. Within these documents you will find information on how to develop JavaScript and C# applications, build and integrate Add-Ins and use MyGeotab with third-party systems.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015387',
#   'type': 'PushEvent',
#   'actor': {'id': 36005947,
#    'login': 'tomotargz',
#    'display_login': 'tomotargz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tomotargz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36005947?'},
#   'repo': {'id': 279315632,
#    'name': 'tomotargz/chibicc',
#    'url': 'https://api.github.com/repos/tomotargz/chibicc'},
#   'payload': {'push_id': 5366082167,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8fe603893820796f8cd52a0a99f097794d32c318',
#    'before': '11bdd08cff0acdce22e27298933b017dcfff8644',
#    'commits': [{'sha': '8fe603893820796f8cd52a0a99f097794d32c318',
#      'author': {'email': 'nakamuratomota@gmail.com', 'name': 'tomotargz'},
#      'message': 'Allow enum addition and subtraction',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tomotargz/chibicc/commits/8fe603893820796f8cd52a0a99f097794d32c318'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015381',
#   'type': 'CreateEvent',
#   'actor': {'id': 45699331,
#    'login': 'sweetdarkness',
#    'display_login': 'sweetdarkness',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sweetdarkness',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45699331?'},
#   'repo': {'id': 279316482,
#    'name': 'sweetdarkness/hyperskill-python-zookeeper',
#    'url': 'https://api.github.com/repos/sweetdarkness/hyperskill-python-zookeeper'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Zookeper project of Hyperskill Jetbrains Academy Python Developer course',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015385',
#   'type': 'CreateEvent',
#   'actor': {'id': 2253671,
#    'login': 'PsychoSid',
#    'display_login': 'PsychoSid',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PsychoSid',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2253671?'},
#   'repo': {'id': 279316929,
#    'name': 'PsychoSid/acm',
#    'url': 'https://api.github.com/repos/PsychoSid/acm'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015372',
#   'type': 'PushEvent',
#   'actor': {'id': 52348991,
#    'login': 'skj1991',
#    'display_login': 'skj1991',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/skj1991',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52348991?'},
#   'repo': {'id': 194423811,
#    'name': 'skj1991/learn-co-sandbox',
#    'url': 'https://api.github.com/repos/skj1991/learn-co-sandbox'},
#   'payload': {'push_id': 5366082160,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '1cceb134368804be40f4d08fa617610ad91f9792',
#    'before': 'd7ede3b50958237d937ad86d7a3914840dca7ea5',
#    'commits': [{'sha': '1cceb134368804be40f4d08fa617610ad91f9792',
#      'author': {'email': 'stacykjohns@icloud.com', 'name': 'Stacy Johns'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/skj1991/learn-co-sandbox/commits/1cceb134368804be40f4d08fa617610ad91f9792'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015349',
#   'type': 'PushEvent',
#   'actor': {'id': 10508077,
#    'login': 'w3liu',
#    'display_login': 'w3liu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/w3liu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10508077?'},
#   'repo': {'id': 185997645,
#    'name': 'w3liu/algorithm',
#    'url': 'https://api.github.com/repos/w3liu/algorithm'},
#   'payload': {'push_id': 5366082150,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1bcf8b506eb980e610671b4b8b3c829409eefd91',
#    'before': 'ac66906f35f9ca57ab796e2788a7b06d8e407ded',
#    'commits': [{'sha': '1bcf8b506eb980e610671b4b8b3c829409eefd91',
#      'author': {'email': 'w3liu@qq.com', 'name': 'w3liu'},
#      'message': '新增 图片',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/w3liu/algorithm/commits/1bcf8b506eb980e610671b4b8b3c829409eefd91'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:53Z'},
#  {'id': '12889015363',
#   'type': 'PushEvent',
#   'actor': {'id': 4889856,
#    'login': 'TheMallen',
#    'display_login': 'TheMallen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TheMallen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4889856?'},
#   'repo': {'id': 278340713,
#    'name': 'TheMallen/SaddleUp',
#    'url': 'https://api.github.com/repos/TheMallen/SaddleUp'},
#   'payload': {'push_id': 5366082159,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '5126d0f5c0be00f82d5d83d5cafbb056839e92b7',
#    'before': 'f7a5f4e4f127a3a57839b9e012761655ce28f141',
#    'commits': [{'sha': '559eadd67ea3a3cbfdae848c675499b239c29c82',
#      'author': {'email': 'mathew.allen@shopify.com', 'name': 'Mathew  Allen'},
#      'message': 'v0.5.1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TheMallen/SaddleUp/commits/559eadd67ea3a3cbfdae848c675499b239c29c82'},
#     {'sha': '5126d0f5c0be00f82d5d83d5cafbb056839e92b7',
#      'author': {'email': 'mathew.allen@shopify.com', 'name': 'Mathew  Allen'},
#      'message': '🗒️ fix README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TheMallen/SaddleUp/commits/5126d0f5c0be00f82d5d83d5cafbb056839e92b7'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015357',
#   'type': 'PushEvent',
#   'actor': {'id': 57315983,
#    'login': 'xcaq',
#    'display_login': 'xcaq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xcaq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57315983?'},
#   'repo': {'id': 279036287,
#    'name': 'xcaq/xcaq',
#    'url': 'https://api.github.com/repos/xcaq/xcaq'},
#   'payload': {'push_id': 5366082155,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '36dd60571614cb9865ace75ce28813924949bb8a',
#    'before': 'a5376cb17a7e2a20ff5e1878ae999dac8ca017b5',
#    'commits': [{'sha': '36dd60571614cb9865ace75ce28813924949bb8a',
#      'author': {'email': 'swipduces@yandex.com', 'name': 'Kirill Feschenko'},
#      'message': 'update info',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xcaq/xcaq/commits/36dd60571614cb9865ace75ce28813924949bb8a'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015353',
#   'type': 'PushEvent',
#   'actor': {'id': 12226982,
#    'login': 'nicomori',
#    'display_login': 'nicomori',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nicomori',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12226982?'},
#   'repo': {'id': 279253209,
#    'name': 'nicomori/deliveryherodemo',
#    'url': 'https://api.github.com/repos/nicomori/deliveryherodemo'},
#   'payload': {'push_id': 5366082154,
#    'size': 4,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd696b2909374f858e3d3b70b138d2cf16992e9a4',
#    'before': '77ebfab33835ad138677e09b9878912c0223f97b',
#    'commits': [{'sha': '82ca40dc9446532c34bc42a9599e4f257b6c0c15',
#      'author': {'email': 'nicolas.mori@gmail.com', 'name': 'Nicolas Mori'},
#      'message': 'adding testing locally',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/nicomori/deliveryherodemo/commits/82ca40dc9446532c34bc42a9599e4f257b6c0c15'},
#     {'sha': 'ecd91f24944b1804f5a0f2c7f46db902a2f2f731',
#      'author': {'email': 'nicolas.mori@gmail.com', 'name': 'Nicolas Mori'},
#      'message': 'adding testing locally',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/nicomori/deliveryherodemo/commits/ecd91f24944b1804f5a0f2c7f46db902a2f2f731'},
#     {'sha': '8f0e77eed019db37887d1b4badf36c47adbeedea',
#      'author': {'email': 'nicolas.mori@gmail.com', 'name': 'Nicolas Mori'},
#      'message': 'cleaned',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/nicomori/deliveryherodemo/commits/8f0e77eed019db37887d1b4badf36c47adbeedea'},
#     {'sha': 'd696b2909374f858e3d3b70b138d2cf16992e9a4',
#      'author': {'email': 'nicolas.mori@gmail.com', 'name': 'Nicolas Mori'},
#      'message': 'Merge pull request #6 from nicomori/testing_locally\n\nTesting locally',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nicomori/deliveryherodemo/commits/d696b2909374f858e3d3b70b138d2cf16992e9a4'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:54Z'},
#  {'id': '12889015336',
#   'type': 'PushEvent',
#   'actor': {'id': 24788222,
#    'login': 'sw586',
#    'display_login': 'sw586',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sw586',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24788222?'},
#   'repo': {'id': 249485229,
#    'name': 'sw586/img',
#    'url': 'https://api.github.com/repos/sw586/img'},
#   'payload': {'push_id': 5366082142,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '98adda32787651e7a61ccbf736fda127725cb46b',
#    'before': '9c171c2e23125f9de980441a6bb9e7f1978b733e',
#    'commits': [{'sha': '98adda32787651e7a61ccbf736fda127725cb46b',
#      'author': {'email': 'sw586@126.com', 'name': 'sw586'},
#      'message': 'Uploaded',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sw586/img/commits/98adda32787651e7a61ccbf736fda127725cb46b'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:53Z'},
#  {'id': '12889015335',
#   'type': 'PushEvent',
#   'actor': {'id': 32233166,
#    'login': 'KathyFeiyang',
#    'display_login': 'KathyFeiyang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KathyFeiyang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32233166?'},
#   'repo': {'id': 273538041,
#    'name': 'googleinterns/voter-central',
#    'url': 'https://api.github.com/repos/googleinterns/voter-central'},
#   'payload': {'push_id': 5366082136,
#    'size': 27,
#    'distinct_size': 1,
#    'ref': 'refs/heads/kathy_location_info_compilation',
#    'head': '10f684658bbcab45ff238c3c6e32f751b4e2f6b5',
#    'before': 'aa3151b300eaf6f6ed63b914206114b5046b00a4',
#    'commits': [{'sha': '931482ee816e7515e022b136eb8a2534f69cc8fb',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': 'Adds education page with videos related to voting and elections.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/931482ee816e7515e022b136eb8a2534f69cc8fb'},
#     {'sha': '74044da47d2f72c27f8b36137a4f45345c81888b',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': 'resolved all comments',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/74044da47d2f72c27f8b36137a4f45345c81888b'},
#     {'sha': 'e051294949b1b277a79a2ab5d1e035d01a3239d5',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': 'broke up long line.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/e051294949b1b277a79a2ab5d1e035d01a3239d5'},
#     {'sha': '0cde438c80455d08afab4db932e5b55c61d48df7',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': 'broke up long line.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/0cde438c80455d08afab4db932e5b55c61d48df7'},
#     {'sha': 'bc1b250cff09a380471dbc3ebd5e1af39ae4be93',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': 'resolved comments',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/bc1b250cff09a380471dbc3ebd5e1af39ae4be93'},
#     {'sha': '812e0f7060dbd930416acacb45606e7241b5f153',
#      'author': {'email': 'ganewman@google.com', 'name': 'Gabi Newman'},
#      'message': 'Add hardcoded images of tweets to the candidate page.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/812e0f7060dbd930416acacb45606e7241b5f153'},
#     {'sha': '342478ae454cb031856d8c6ea8c602fd44a3eff7',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': 'Resolved all comments',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/342478ae454cb031856d8c6ea8c602fd44a3eff7'},
#     {'sha': '2925d9832d62ea87b6b234db02c2c7737e7a7a29',
#      'author': {'email': '32233166+KathyFeiyang@users.noreply.github.com',
#       'name': 'KathyFeiyang'},
#      'message': 'Merge pull request #6 from googleinterns/kathy_dev\n\nWrite the HTML structure for the news articles section (candidate page) and search results for location-specific info (directory page).',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/2925d9832d62ea87b6b234db02c2c7737e7a7a29'},
#     {'sha': 'e1e80b76297c07554869b1f8730f5431f976438f',
#      'author': {'email': 'ganewman@google.com', 'name': 'Gabi Newman'},
#      'message': 'Modify html tags.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/e1e80b76297c07554869b1f8730f5431f976438f'},
#     {'sha': '38da8b0b2886a26eeda0146c7cd55b85e5669365',
#      'author': {'email': 'ganewman@google.com', 'name': 'Gabi Newman'},
#      'message': 'Merge pull request #7 from googleinterns/GabiDev\n\nAdd hard-coded images of tweets to the candidate page.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/38da8b0b2886a26eeda0146c7cd55b85e5669365'},
#     {'sha': '733dbbb3f94f7436f31039605d92f1dfe5f5eedd',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': 'Resolved comments',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/733dbbb3f94f7436f31039605d92f1dfe5f5eedd'},
#     {'sha': 'a36afc8e023caa083ab761af147689c1dbb76bdb',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': "Merge branch 'master' into Travis_Dev",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/a36afc8e023caa083ab761af147689c1dbb76bdb'},
#     {'sha': '8386e18ef91209fdfeb49331389ae6831e115393',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': 'Adds education page to nav',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/8386e18ef91209fdfeb49331389ae6831e115393'},
#     {'sha': 'ef14ba93d8432a72bb3534c12aa21cd396270d0d',
#      'author': {'email': 'ty12101999@gmail.com', 'name': 'tjyoung99'},
#      'message': 'Resolves only comment',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/ef14ba93d8432a72bb3534c12aa21cd396270d0d'},
#     {'sha': 'bde6b320c25d6f9c4ca70f481e509420a12b9a6f',
#      'author': {'email': '40397667+tjyoung99@users.noreply.github.com',
#       'name': 'tjyoung99'},
#      'message': 'Merge pull request #5 from googleinterns/Travis_Dev\n\nAdds education page with videos related to voting and elections.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/bde6b320c25d6f9c4ca70f481e509420a12b9a6f'},
#     {'sha': 'af636ad6915cc327ec41043a3b5ae0d69d8d49cb',
#      'author': {'email': 'feiyangyu@google.com', 'name': 'Feiyang Yu'},
#      'message': 'Revise comments.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/af636ad6915cc327ec41043a3b5ae0d69d8d49cb'},
#     {'sha': 'b1cc4e435d4e4a15c74782520568401f0b83324f',
#      'author': {'email': 'feiyangyu@google.com', 'name': 'Feiyang Yu'},
#      'message': 'Change data type for candidate incumbency in the database and code, and fix issue with extracting the candidates corresponding to particular positions.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/b1cc4e435d4e4a15c74782520568401f0b83324f'},
#     {'sha': '1858f6ff18edce807c9ef3f4f4396e60d4227d58',
#      'author': {'email': 'feiyangyu@google.com', 'name': 'Feiyang Yu'},
#      'message': 'Refactor code for constructing backend position and candidate information. Clarify assumptions about data formats.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/1858f6ff18edce807c9ef3f4f4396e60d4227d58'},
#     {'sha': '825e4b039c34f9a20be7a0ce6c0a8a82dd80bddd',
#      'author': {'email': 'feiyangyu@google.com', 'name': 'Feiyang Yu'},
#      'message': 'Revise comments and make code more succinct.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/825e4b039c34f9a20be7a0ce6c0a8a82dd80bddd'},
#     {'sha': 'e8a4278626804b1dc0410216b6677a074f83c8e6',
#      'author': {'email': '32233166+KathyFeiyang@users.noreply.github.com',
#       'name': 'KathyFeiyang'},
#      'message': 'Merge pull request #8 from googleinterns/kathy_dev\n\nImplement frontend, backend and database communication for location-based search results (directory page) and the news articles component (candidate page). Query for and serve dynamic content in designed HTML structure.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/googleinterns/voter-central/commits/e8a4278626804b1dc0410216b6677a074f83c8e6'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:53Z',
#   'org': {'id': 63743512,
#    'login': 'googleinterns',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/googleinterns',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63743512?'}},
#  {'id': '12889015329',
#   'type': 'PushEvent',
#   'actor': {'id': 31464556,
#    'login': 'Meirian',
#    'display_login': 'Meirian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Meirian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31464556?'},
#   'repo': {'id': 247873293,
#    'name': 'Meirian/LaTeX',
#    'url': 'https://api.github.com/repos/Meirian/LaTeX'},
#   'payload': {'push_id': 5366082139,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '50273b8f7b20366d22f55bc5db21577edd81100a',
#    'before': '11bfd4af36024db5c501fcca78eae7c6c46bf076',
#    'commits': [{'sha': '50273b8f7b20366d22f55bc5db21577edd81100a',
#      'author': {'email': 'meirian.lovelacetozer@gmail.com', 'name': 'Meirian'},
#      'message': 'GitBook: [master] one page modified',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Meirian/LaTeX/commits/50273b8f7b20366d22f55bc5db21577edd81100a'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:53Z'},
#  {'id': '12889015322',
#   'type': 'PushEvent',
#   'actor': {'id': 60684241,
#    'login': 'shenyouran',
#    'display_login': 'shenyouran',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shenyouran',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60684241?'},
#   'repo': {'id': 266474674,
#    'name': 'shenyouran/shenyouran.github.io',
#    'url': 'https://api.github.com/repos/shenyouran/shenyouran.github.io'},
#   'payload': {'push_id': 5366082133,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '17653db583329d7d107e1b5a67808a3fc1289579',
#    'before': '770b9df09bf040d18bb4c5c72438e34efc2a7d5f',
#    'commits': [{'sha': '17653db583329d7d107e1b5a67808a3fc1289579',
#      'author': {'email': 'ericshen4@yeah.net', 'name': 'System Administrator'},
#      'message': 'Site updated: 2020-07-13 21:57:03',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shenyouran/shenyouran.github.io/commits/17653db583329d7d107e1b5a67808a3fc1289579'}]},
#   'public': True,
#   'created_at': '2020-07-13T13:54:53Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
# 利用 https://alexwohlbruck.github.io/cat-facts/ 做r.text練習
import requests
import json
r = requests.get('https://cat-fact.herokuapp.com/facts')
print(r.text)
# Out:
# {"all":[{"_id":"58e007f50aac31001185ecf8","text":"A group of cats is called a clowder.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":12,"userUpvoted":null},{"_id":"58e008b80aac31001185ed0d","text":"Adult cats only meow to communicate with humans.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":12,"userUpvoted":null},{"_id":"5887e1d85c873e0011036889","text":"Cats make about 100 different sounds. Dogs make only about 10.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":11,"userUpvoted":null},{"_id":"58e009420aac31001185ed11","text":"Basically all cartoon cats lied to us: Raw fish is off the table for cats as well.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":11,"userUpvoted":null},{"_id":"5b4910ae0508220014ccfe90","text":"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":11,"userUpvoted":null},{"_id":"58f8d7b98098c80011c50a42","text":"A man named Ernest Misko gave marijuana tinctures to his 24-year-old cat, Borzo. In a couple of days, he was walking normally again, pain-free. Veterinarians in many states are still not legally allowed to prescribe cannabis to cats, even in states that have legalized medicinal marijuana for humans.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":10,"userUpvoted":null},{"_id":"58e00b970aac31001185edf9","text":"A house cat is faster than Usain Bolt.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":10,"userUpvoted":null},{"_id":"58e00b450aac31001185ed21","text":"There are 45 Hemingway cats living at the author's former home in Key West, Fla.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":9,"userUpvoted":null},{"_id":"5b4911940508220014ccfe94","text":"By the time a cat is 9 years old, it will only have been awake for three years of its life.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":9,"userUpvoted":null},{"_id":"58e00af60aac31001185ed1d","text":"It was illegal to slay cats in ancient Egypt, in large part because they provided the great service of controlling the rat population.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":8,"userUpvoted":null},{"_id":"5e236d6bdc76630015d4c51f","type":"cat","text":"gato loves grace","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":8,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":8,"userUpvoted":null},{"_id":"58e009650aac31001185ed13","text":"In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":7,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":7,"userUpvoted":null},{"_id":"59a60b8e6acf530020f3586e","text":"Cat owners are 17% more l ...

# %%
# 利用 https://alexwohlbruck.github.io/cat-facts/ 做json.loads練習
import requests
import json
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e007f50aac31001185ecf8',
#    'text': 'A group of cats is called a clowder.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 12,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 12,
#    'userUpvoted': None},
#   {'_id': '5887e1d85c873e0011036889',
#    'text': 'Cats make about 100 different sounds. Dogs make only about 10.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 11,
#    'userUpvoted': None},
#   {'_id': '58e009420aac31001185ed11',
#    'text': 'Basically all cartoon cats lied to us: Raw fish is off the table for cats as well.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 11,
#    'userUpvoted': None},
#   {'_id': '5b4910ae0508220014ccfe90',
#    'text': 'Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 11,
#    'userUpvoted': None},
#   {'_id': '58f8d7b98098c80011c50a42',
#    'text': 'A man named Ernest Misko gave marijuana tinctures to his 24-year-old cat, Borzo. In a couple of days, he was walking normally again, pain-free. Veterinarians in many states are still not legally allowed to prescribe cannabis to cats, even in states that have legalized medicinal marijuana for humans.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 10,
#    'userUpvoted': None},
#   {'_id': '58e00b970aac31001185edf9',
#    'text': 'A house cat is faster than Usain Bolt.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 10,
#    'userUpvoted': None},
#   {'_id': '58e00b450aac31001185ed21',
#    'text': "There are 45 Hemingway cats living at the author's former home in Key West, Fla.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '58e00af60aac31001185ed1d',
#    'text': 'It was illegal to slay cats in ancient Egypt, in large part because they provided the great service of controlling the rat population.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 8,
#    'userUpvoted': None},
#   {'_id': '5e236d6bdc76630015d4c51f',
#    'type': 'cat',
#    'text': 'gato loves grace',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 8,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 8,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 7,
#    'userUpvoted': None},
#   {'_id': '58e009550aac31001185ed12',
#    'text': 'The oldest cat video on YouTube dates back to 1894.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e008340aac31001185ecfb',
#    'text': 'Cats sleep 70% of their lives.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f87db9a11040c4a16343f',
#    'text': 'The goddess of love, beauty, and fertility in Norse mythology, Freyja was the first cat lady. She is depicted in stories as riding a chariot that was drawn by cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5894af975cdc7400113ef7f9',
#    'text': 'The technical term for a cat’s hairball is a bezoar.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b0c5e3e7ab3c50014df65fe',
#    'text': 'People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00a000aac31001185ed15',
#    'text': 'Female cats are typically right-pawed while male cats are typically left-pawed.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00a1a0aac31001185ed18',
#    'text': 'Cats and humans have nearly identical sections of the brain that control emotion.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e0088b0aac31001185ed09',
#    'text': "The world's largest cat measured 48.5 inches long.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00a7e0aac31001185ed19',
#    'text': "A cat's cerebral cortex (the part of the brain in charge of cognitive information processing) has 300 million neurons, compared with a dog's 160 million.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b1f0aac31001185ed1e',
#    'text': 'In the 15th century, Pope Innocent VIII began ordering the killing of cats, pronouncing them demonic.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58f89cff11658e00113ddd26',
#    'text': 'Cats love to eat olives or for that matter anything preserved in brine.',
#    'type': 'cat',
#    'user': {'_id': '58f89c8d11658e00113ddd24',
#     'name': {'first': 'Malvika', 'last': 'Tewari'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
# ...
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e83ff18f53272001515690c',
#    'type': 'cat',
#    'text': 'Cats are capable of walking very precisely because, like all felines, they directly register; that is, they place each hind paw (almost) directly in the print of the corresponding fore paw, minimizing noise and visible tracks. This also provides sure footing for their hind paws when they navigate rough terrain.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e80e7cc2d4b850015003072',
#    'type': 'cat',
#    'text': 'Cats can climb on trees faster than squirels.',
#    'user': {'_id': '5e80e6c72d4b85001500306e',
#     'name': {'first': 'Łukasz', 'last': 'Wiktorko'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eafdaf354ad960017b3703d',
#    'type': 'cat',
#    'text': 'Yjyyu.',
#    'user': {'_id': '5eafdad954ad960017b37038',
#     'name': {'first': 'Lulu', 'last': 'Dauphin'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ebbf5dd8046d00017776020',
#    'type': 'cat',
#    'text': 'Cats are fat, sometimes.',
#    'user': {'_id': '5ebbf5cd8046d0001777601f',
#     'name': {'first': 'George', 'last': 'Miguel'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec4aad30c796a00174d7b26',
#    'type': 'cat',
#    'text': 'Sss.',
#    'user': {'_id': '5ec4a7d60c796a00174d7b25',
#     'name': {'first': 'Minh', 'last': 'Nguyễn'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec93d1de11bba0017c67e19',
#    'type': 'cat',
#    'text': 'In a sense, cats can see in the dark.',
#    'user': {'_id': '5ec93c89e11bba0017c67e18',
#     'name': {'first': 'Mandy', 'last': 'c'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb032ab0d92c0017cab214',
#    'type': 'cat',
#    'text': 'Cats are the best pets.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb0333b0d92c0017cab215',
#    'type': 'cat',
#    'text': 'Hello cats.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecdda946253f20017f53ec5',
#    'type': 'cat',
#    'text': 'Cats love womans, dog loves mans.',
#    'user': {'_id': '5ecdda686253f20017f53ec4',
#     'name': {'first': 'Jorge Alberto', 'last': 'Gil Rendon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece7253a0d2ec00178ae28c',
#    'type': 'cat',
#    'text': 'Cat is cat.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece9fa9a0d2ec00178ae28e',
#    'type': 'cat',
#    'text': 'Z.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ed11e643c15f700172e3856',
#    'type': 'cat',
#    'text': 'Los gatos tienen más huesos que los seres humanos, nos ganan por 24.',
#    'user': {'_id': '5ed11e353c15f700172e3855',
#     'name': {'first': 'Luciano', 'last': 'Garrido Sepulveda'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eddfb501ed5570017aaf3b9',
#    'type': 'cat',
#    'text': 'Take a try.',
#    'user': {'_id': '5eddfb351ed5570017aaf3b8',
#     'name': {'first': 'calix', 'last': 'cheng'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eebc851515a030017471024',
#    'type': 'cat',
#    'text': 'Cats are cats.',
#    'user': {'_id': '5eebc848515a030017471023',
#     'name': {'first': 'Ricky', 'last': 'Chon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ef556dff61f300017030d4c',
#    'type': 'cat',
#    'text': 'Lucy, the oldest cat ever, lived to be 39 years old which is equivalent to 172 cat years.',
#    'user': {'_id': '5e1a9b981fd6150015fa736f',
#     'name': {'first': 'Andrew', 'last': 'Pobrica'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ef5bbdbf61f300017030d4f',
#    'type': 'cat',
#    'text': 'Fdfd.',
#    'user': {'_id': '5ef5bbcdf61f300017030d4e',
#     'name': {'first': 'Touch', 'last': 'Akhil'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f0371215ac1ed0017c647a9',
#    'type': 'cat',
#    'text': 'Cxcbc.',
#    'user': {'_id': '5f03708f5ac1ed0017c647a8',
#     'name': {'first': 'Marylange', 'last': 'Souza'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f03712d5ac1ed0017c647aa',
#    'type': 'cat',
#    'text': 'Jfhfhf.',
#    'user': {'_id': '5f03708f5ac1ed0017c647a8',
#     'name': {'first': 'Marylange', 'last': 'Souza'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5f0a15090fc09b00174aec96',
#    'type': 'cat',
#    'text': '1123405258.',
#    'user': {'_id': '5f0a15010fc09b00174aec95',
#     'name': {'first': 'nelson enrique', 'last': 'redondo b'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ea7496761cd4d0017498a94',
#    'type': 'cat',
#    'text': 'Ancient sailors believed that cats were magic and would often risk their own lives, even in an "every man for himself" situation, to save a cat from a sinking ship. All ships had at least one ship\'s cat as cats would eat the rats that have always plagued ships. The ship\'s cat would often be given a rank and sailors would generally take excessively good care of their cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eaafca69105ce00177573de',
#    'type': 'cat',
#    'text': 'Cats sleep most of the time.',
#    'user': {'_id': '5ea977d1cd53d20017d7d8b2',
#     'name': {'first': 'Quang', 'last': 'Pham'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
# 利用 https://opendata.epa.gov.tw/ws/Data/AQI/?$format=json 做練習
import requests
import json
r = requests.get('https://opendata.epa.gov.tw/ws/Data/AQI/?$format=json')
json.loads(r.text)
# Out:
# [{'SiteName': '臺南(北門)',
#   'County': '臺南市',
#   'AQI': '23',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '0.1',
#   'CO': '0.06',
#   'CO_8hr': '0.1',
#   'O3': '24',
#   'O3_8hr': '25',
#   'PM10': '9',
#   'PM2.5': '2',
#   'NO2': '0.7',
#   'NOx': '0.3',
#   'NO': '-0.4',
#   'WindSpeed': '1.4',
#   'WindDirec': '244',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '1',
#   'PM10_AVG': '5',
#   'SO2_AVG': '1',
#   'Longitude': '120.124444',
#   'Latitude': '23.264722',
#   'SiteId': '310'},
#  {'SiteName': '屏東(琉球)',
#   'County': '屏東縣',
#   'AQI': '23',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.2',
#   'CO': '0.2',
#   'CO_8hr': '0.2',
#   'O3': '23',
#   'O3_8hr': '25',
#   'PM10': '10',
#   'PM2.5': '5',
#   'NO2': '2.2',
#   'NOx': '2.5',
#   'NO': '0.3',
#   'WindSpeed': '0.3',
#   'WindDirec': '202',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '8',
#   'SO2_AVG': '3',
#   'Longitude': '120.377222',
#   'Latitude': '22.352222',
#   'SiteId': '204'},
#  {'SiteName': '臺南(麻豆)',
#   'County': '臺南市',
#   'AQI': '17',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.7',
#   'CO': '0.21',
#   'CO_8hr': '0.2',
#   'O3': '5.6',
#   'O3_8hr': '18',
#   'PM10': '11',
#   'PM2.5': '6',
#   'NO2': '15',
#   'NOx': '21',
#   'NO': '5.7',
#   'WindSpeed': '0.5',
#   'WindDirec': '125',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '5',
#   'PM10_AVG': '11',
#   'SO2_AVG': '2',
#   'Longitude': '120.245831',
#   'Latitude': '23.179047',
#   'SiteId': '203'},
#  {'SiteName': '彰化(大城)',
#   'County': '彰化縣',
#   'AQI': '19',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.4',
#   'CO': '0.1',
#   'CO_8hr': '0.1',
#   'O3': '11',
#   'O3_8hr': '21',
#   'PM10': '10',
#   'PM2.5': '3',
#   'NO2': '7.9',
#   'NOx': '8.9',
#   'NO': '1',
#   'WindSpeed': '0.4',
#   'WindDirec': '167',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '2',
#   'PM10_AVG': '8',
#   'SO2_AVG': '1',
#   'Longitude': '120.273117',
#   'Latitude': '23.843139',
#   'SiteId': '202'},
#  {'SiteName': '富貴角',
#   'County': '新北市',
#   'AQI': '34',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.1',
#   'CO': '0.12',
#   'CO_8hr': '0.1',
#   'O3': '43',
#   'O3_8hr': '36',
#   'PM10': '18',
#   'PM2.5': '11',
#   'NO2': '2.8',
#   'NOx': '2.9',
#   'NO': '0.1',
#   'WindSpeed': '0.5',
#   'WindDirec': '116',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '11',
#   'PM10_AVG': '15',
#   'SO2_AVG': '1',
#   'Longitude': '121.536763',
#   'Latitude': '25.298562',
#   'SiteId': '84'},
#  {'SiteName': '麥寮',
#   'County': '雲林縣',
#   'AQI': '20',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.2',
#   'CO': '0.23',
#   'CO_8hr': '0.1',
#   'O3': '12',
#   'O3_8hr': '22',
#   'PM10': '21',
#   'PM2.5': '4',
#   'NO2': '10',
#   'NOx': '12',
#   'NO': '1.5',
#   'WindSpeed': '2.2',
#   'WindDirec': '210',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '13',
#   'SO2_AVG': '2',
#   'Longitude': '120.251825',
#   'Latitude': '23.753506',
#   'SiteId': '83'},
#  {'SiteName': '關山',
#   'County': '臺東縣',
#   'AQI': '18',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '',
#   'CO': '-',
#   'CO_8hr': '',
#   'O3': '9.7',
#   'O3_8hr': '13',
#   'PM10': '8',
#   'PM2.5': '6',
#   'NO2': '2.4',
#   'NOx': '3.6',
#   'NO': '1.2',
#   'WindSpeed': '0.6',
#   'WindDirec': '206',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '7',
#   'SO2_AVG': '2',
#   'Longitude': '121.161933',
#   'Latitude': '23.045083',
#   'SiteId': '80'},
#  {'SiteName': '馬公',
#   'County': '澎湖縣',
#   'AQI': '29',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '4.3',
#   'CO': '0.37',
#   'CO_8hr': '0.2',
#   'O3': '22',
#   'O3_8hr': '31',
#   'PM10': '17',
#   'PM2.5': '6',
#   'NO2': '9',
#   'NOx': '12',
#   'NO': '2.5',
#   'WindSpeed': '2.3',
#   'WindDirec': '171',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '5',
#   'PM10_AVG': '14',
#   'SO2_AVG': '3',
#   'Longitude': '119.566158',
#   'Latitude': '23.569031',
#   'SiteId': '78'},
#  {'SiteName': '金門',
#   'County': '金門縣',
#   'AQI': '43',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.3',
#   'CO': '0.11',
#   'CO_8hr': '0.1',
#   'O3': '26',
#   'O3_8hr': '46',
#   'PM10': '19',
#   'PM2.5': '3',
#   'NO2': '5.9',
#   'NOx': '6.5',
#   'NO': '0.5',
#   'WindSpeed': '1.8',
#   'WindDirec': '181',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '26',
#   'SO2_AVG': '3',
#   'Longitude': '118.312256',
#   'Latitude': '24.432133',
#   'SiteId': '77'},
#  {'SiteName': '馬祖',
#   'County': '連江縣',
#   'AQI': '59',
#   'Pollutant': '細懸浮微粒',
#   'Status': '普通',
#   'SO2': '2.9',
#   'CO': '0.13',
#   'CO_8hr': '0.1',
#   'O3': '28',
#   'O3_8hr': '36',
#   'PM10': '22',
#   'PM2.5': '20',
#   'NO2': '15',
#   'NOx': '16',
#   'NO': '0.4',
#   'WindSpeed': '4.8',
#   'WindDirec': '206',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '19',
#   'PM10_AVG': '30',
#   'SO2_AVG': '3',
#   'Longitude': '119.949875',
#   'Latitude': '26.160469',
#   'SiteId': '75'},
#  {'SiteName': '埔里',
#   'County': '南投縣',
#   'AQI': '51',
#   'Pollutant': '臭氧八小時',
#   'Status': '普通',
#   'SO2': '3.3',
#   'CO': '0.25',
#   'CO_8hr': '0.2',
#   'O3': '30',
#   'O3_8hr': '55',
#   'PM10': '28',
#   'PM2.5': '12',
#   'NO2': '11',
#   'NOx': '13',
#   'NO': '1.2',
#   'WindSpeed': '0.6',
#   'WindDirec': '158',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '15',
#   'PM10_AVG': '24',
#   'SO2_AVG': '3',
#   'Longitude': '120.967903',
#   'Latitude': '23.968842',
#   'SiteId': '72'},
#  {'SiteName': '復興',
#   'County': '高雄市',
#   'AQI': '18',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.3',
#   'CO': '0.16',
#   'CO_8hr': '0.2',
#   'O3': '15',
#   'O3_8hr': '19',
#   'PM10': '8',
#   'PM2.5': '6',
#   'NO2': '7.5',
#   'NOx': '8.9',
#   'NO': '1.4',
#   'WindSpeed': '1',
#   'WindDirec': '209',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '9',
#   'SO2_AVG': '',
#   'Longitude': '120.312017',
#   'Latitude': '22.608711',
#   'SiteId': '71'},
#  {'SiteName': '永和',
#   'County': '新北市',
#   'AQI': '40',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.8',
#   'CO': '0.65',
#   'CO_8hr': '0.9',
#   'O3': '9.8',
#   'O3_8hr': '38',
#   'PM10': '16',
#   'PM2.5': '7',
#   'NO2': '16',
#   'NOx': '27',
#   'NO': '11',
#   'WindSpeed': '1.3',
#   'WindDirec': '110',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '24',
#   'SO2_AVG': '3',
#   'Longitude': '121.516306',
#   'Latitude': '25.017',
#   'SiteId': '70'},
#  {'SiteName': '竹山',
#   'County': '南投縣',
#   'AQI': '32',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.3',
#   'CO': '0.13',
#   'CO_8hr': '0.1',
#   'O3': '15',
#   'O3_8hr': '35',
#   'PM10': '20',
#   'PM2.5': '9',
#   'NO2': '7.6',
#   'NOx': '9.9',
#   'NO': '2.3',
#   'WindSpeed': '1.9',
#   'WindDirec': '190',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '9',
#   'PM10_AVG': '21',
#   'SO2_AVG': '2',
#   'Longitude': '120.677306',
#   'Latitude': '23.756389',
#   'SiteId': '69'},
#  {'SiteName': '中壢',
#   'County': '桃園市',
#   'AQI': '37',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3.7',
#   'CO': '0.41',
#   'CO_8hr': '0.8',
#   'O3': '2.9',
#   'O3_8hr': '17',
#   'PM10': '21',
#   'PM2.5': '12',
#   'NO2': '24',
#   'NOx': '32',
#   'NO': '7.2',
#   'WindSpeed': '0.5',
#   'WindDirec': '5.5',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '22',
#   'SO2_AVG': '3',
#   'Longitude': '121.221667',
#   'Latitude': '24.953278',
#   'SiteId': '68'},
#  {'SiteName': '三重',
#   'County': '新北市',
#   'AQI': '55',
#   'Pollutant': '細懸浮微粒',
#   'Status': '普通',
#   'SO2': '2',
#   'CO': '1.33',
#   'CO_8hr': '0.9',
#   'O3': '-',
#   'O3_8hr': '',
#   'PM10': '17',
#   'PM2.5': '19',
#   'NO2': '16',
#   'NOx': '70',
#   'NO': '54',
#   'WindSpeed': '',
#   'WindDirec': '',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '17',
#   'PM10_AVG': '27',
#   'SO2_AVG': '3',
#   'Longitude': '121.493806',
#   'Latitude': '25.072611',
#   'SiteId': '67'},
#  {'SiteName': '冬山',
#   'County': '宜蘭縣',
#   'AQI': '26',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '0.6',
#   'CO': '0.13',
#   'CO_8hr': '0.1',
#   'O3': '11',
#   'O3_8hr': '18',
#   'PM10': '15',
#   'PM2.5': '8',
#   'NO2': '3.5',
#   'NOx': '3.9',
#   'NO': '0.4',
#   'WindSpeed': '0.9',
#   'WindDirec': '191',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '8',
#   'PM10_AVG': '19',
#   'SO2_AVG': '1',
#   'Longitude': '121.792928',
#   'Latitude': '24.632203',
#   'SiteId': '66'},
#  {'SiteName': '宜蘭',
#   'County': '宜蘭縣',
#   'AQI': '19',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.2',
#   'CO': '0.24',
#   'CO_8hr': '0.1',
#   'O3': '8.6',
#   'O3_8hr': '15',
#   'PM10': '14',
#   'PM2.5': '8',
#   'NO2': '9.8',
#   'NOx': '11',
#   'NO': '0.9',
#   'WindSpeed': '1.8',
#   'WindDirec': '331',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '15',
#   'SO2_AVG': '2',
#   'Longitude': '121.746394',
#   'Latitude': '24.747917',
#   'SiteId': '65'},
#  {'SiteName': '陽明',
#   'County': '臺北市',
#   'AQI': '43',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.6',
#   'CO': '0.24',
#   'CO_8hr': '0.2',
#   'O3': '46',
#   'O3_8hr': '46',
#   'PM10': '20',
#   'PM2.5': '14',
#   'NO2': '7.4',
#   'NOx': '7.8',
#   'NO': '0.4',
#   'WindSpeed': '',
#   'WindDirec': '',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '21',
#   'SO2_AVG': '1',
#   'Longitude': '121.529583',
#   'Latitude': '25.182722',
#   'SiteId': '64'},
#  {'SiteName': '花蓮',
#   'County': '花蓮縣',
#   'AQI': '20',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.5',
#   'CO': '0.13',
#   'CO_8hr': '0.1',
#   'O3': '16',
#   'O3_8hr': '20',
#   'PM10': '13',
#   'PM2.5': '10',
#   'NO2': '4',
#   'NOx': '5.3',
#   'NO': '1.3',
#   'WindSpeed': '0.6',
#   'WindDirec': '255',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '11',
#   'SO2_AVG': '1',
#   'Longitude': '121.599769',
#   'Latitude': '23.971306',
#   'SiteId': '63'},
#  {'SiteName': '臺東',
#   'County': '臺東縣',
#   'AQI': '19',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '0.7',
#   'CO': '0.13',
#   'CO_8hr': '0.2',
#   'O3': '21',
#   'O3_8hr': '20',
#   'PM10': '12',
#   'PM2.5': '3',
#   'NO2': '2.3',
#   'NOx': '2.4',
#   'NO': '0.1',
#   'WindSpeed': '1.2',
#   'WindDirec': '331',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '2',
#   'PM10_AVG': '11',
#   'SO2_AVG': '1',
#   'Longitude': '121.15045',
#   'Latitude': '22.755358',
#   'SiteId': '62'},
#  {'SiteName': '恆春',
#   'County': '屏東縣',
#   'AQI': '20',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '0.9',
#   'CO': '0.03',
#   'CO_8hr': '0.1',
#   'O3': '21',
#   'O3_8hr': '22',
#   'PM10': '4',
#   'PM2.5': 'ND',
#   'NO2': '0.3',
#   'NOx': '1.8',
#   'NO': '1.5',
#   'WindSpeed': '2.8',
#   'WindDirec': '14',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '5',
#   'SO2_AVG': '1',
#   'Longitude': '120.788928',
#   'Latitude': '21.958069',
#   'SiteId': '61'},
#  {'SiteName': '潮州',
#   'County': '屏東縣',
#   'AQI': '27',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.6',
#   'CO': '0.12',
#   'CO_8hr': '0.1',
#   'O3': '17',
#   'O3_8hr': '24',
#   'PM10': '21',
#   'PM2.5': '9',
#   'NO2': '8.3',
#   'NOx': '8.5',
#   'NO': '0.2',
#   'WindSpeed': '1',
#   'WindDirec': '116',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '8',
#   'PM10_AVG': '20',
#   'SO2_AVG': '2',
#   'Longitude': '120.561175',
#   'Latitude': '22.523108',
#   'SiteId': '60'},
#  {'SiteName': '屏東',
#   'County': '屏東縣',
#   'AQI': '27',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.8',
#   'CO': '0.28',
#   'CO_8hr': '0.2',
#   'O3': '16',
#   'O3_8hr': '29',
#   'PM10': '12',
#   'PM2.5': '3',
#   'NO2': '11',
#   'NOx': '12',
#   'NO': '0.8',
#   'WindSpeed': '0.9',
#   'WindDirec': '56',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '18',
#   'SO2_AVG': '2',
#   'Longitude': '120.488033',
#   'Latitude': '22.673081',
#   'SiteId': '59'},
#  {'SiteName': '小港',
#   'County': '高雄市',
#   'AQI': '18',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.3',
#   'CO': '0.06',
#   'CO_8hr': '0.1',
#   'O3': '14',
#   'O3_8hr': '16',
#   'PM10': '10',
#   'PM2.5': '7',
#   'NO2': '11',
#   'NOx': '13',
#   'NO': '2.1',
#   'WindSpeed': '1.1',
#   'WindDirec': '280',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '5',
#   'PM10_AVG': '12',
#   'SO2_AVG': '2',
#   'Longitude': '120.337736',
#   'Latitude': '22.565833',
#   'SiteId': '58'},
#  {'SiteName': '前鎮',
#   'County': '高雄市',
#   'AQI': '17',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.4',
#   'CO': '0.17',
#   'CO_8hr': '0.2',
#   'O3': '14',
#   'O3_8hr': '18',
#   'PM10': '8',
#   'PM2.5': 'ND',
#   'NO2': '9.6',
#   'NOx': '12',
#   'NO': '2.6',
#   'WindSpeed': '1.1',
#   'WindDirec': '211',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '3',
#   'PM10_AVG': '10',
#   'SO2_AVG': '2',
#   'Longitude': '120.307564',
#   'Latitude': '22.605386',
#   'SiteId': '57'},
#  {'SiteName': '前金',
#   'County': '高雄市',
#   'AQI': '22',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3',
#   'CO': '0.13',
#   'CO_8hr': '0.1',
#   'O3': '22',
#   'O3_8hr': '24',
#   'PM10': '9',
#   'PM2.5': '4',
#   'NO2': '2.9',
#   'NOx': '4.4',
#   'NO': '1.4',
#   'WindSpeed': '1.7',
#   'WindDirec': '251',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '8',
#   'SO2_AVG': '3',
#   'Longitude': '120.288086',
#   'Latitude': '22.632567',
#   'SiteId': '56'},
#  {'SiteName': '左營',
#   'County': '高雄市',
#   'AQI': '22',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.6',
#   'CO': '0.1',
#   'CO_8hr': '0.1',
#   'O3': '21',
#   'O3_8hr': '24',
#   'PM10': '5',
#   'PM2.5': '5',
#   'NO2': '2.6',
#   'NOx': '4',
#   'NO': '1.4',
#   'WindSpeed': '1.2',
#   'WindDirec': '283',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '3',
#   'PM10_AVG': '6',
#   'SO2_AVG': '2',
#   'Longitude': '120.292917',
#   'Latitude': '22.674861',
#   'SiteId': '54'},
#  {'SiteName': '楠梓',
#   'County': '高雄市',
#   'AQI': '21',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.6',
#   'CO': '0.14',
#   'CO_8hr': '0.1',
#   'O3': '21',
#   'O3_8hr': '23',
#   'PM10': '8',
#   'PM2.5': '5',
#   'NO2': '5.8',
#   'NOx': '6.2',
#   'NO': '0.4',
#   'WindSpeed': '1.4',
#   'WindDirec': '318',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '5',
#   'PM10_AVG': '12',
#   'SO2_AVG': '2',
#   'Longitude': '120.328289',
#   'Latitude': '22.733667',
#   'SiteId': '53'},
#  {'SiteName': '林園',
#   'County': '高雄市',
#   'AQI': '24',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.3',
#   'CO': '0.11',
#   'CO_8hr': '0.1',
#   'O3': '25',
#   'O3_8hr': '26',
#   'PM10': '14',
#   'PM2.5': '3',
#   'NO2': '2.9',
#   'NOx': '3',
#   'NO': '0.1',
#   'WindSpeed': '1.4',
#   'WindDirec': '249',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '5',
#   'PM10_AVG': '14',
#   'SO2_AVG': '2',
#   'Longitude': '120.41175',
#   'Latitude': '22.4795',
#   'SiteId': '52'},
#  {'SiteName': '大寮',
#   'County': '高雄市',
#   'AQI': '24',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.6',
#   'CO': '0.21',
#   'CO_8hr': '0.2',
#   'O3': '15',
#   'O3_8hr': '23',
#   'PM10': '15',
#   'PM2.5': '7',
#   'NO2': '11',
#   'NOx': '13',
#   'NO': '1.6',
#   'WindSpeed': '0.5',
#   'WindDirec': '241',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '8',
#   'PM10_AVG': '18',
#   'SO2_AVG': '2',
#   'Longitude': '120.425081',
#   'Latitude': '22.565747',
#   'SiteId': '51'},
#  {'SiteName': '鳳山',
#   'County': '高雄市',
#   'AQI': '21',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1',
#   'CO': '0.33',
#   'CO_8hr': '0.3',
#   'O3': '14',
#   'O3_8hr': '23',
#   'PM10': '9',
#   'PM2.5': '3',
#   'NO2': '9.4',
#   'NOx': '10',
#   'NO': '0.9',
#   'WindSpeed': '1',
#   'WindDirec': '218',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '5',
#   'PM10_AVG': '9',
#   'SO2_AVG': '2',
#   'Longitude': '120.358083',
#   'Latitude': '22.627392',
#   'SiteId': '50'},
#  {'SiteName': '仁武',
#   'County': '高雄市',
#   'AQI': '21',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.7',
#   'CO': '0.12',
#   'CO_8hr': '0.1',
#   'O3': '20',
#   'O3_8hr': '23',
#   'PM10': '7',
#   'PM2.5': '5',
#   'NO2': '5.5',
#   'NOx': '6.1',
#   'NO': '0.6',
#   'WindSpeed': '1.6',
#   'WindDirec': '296',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '7',
#   'SO2_AVG': '3',
#   'Longitude': '120.332631',
#   'Latitude': '22.689056',
#   'SiteId': '49'},
#  {'SiteName': '橋頭',
#   'County': '高雄市',
#   'AQI': '21',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.4',
#   'CO': '0.17',
#   'CO_8hr': '0.1',
#   'O3': '21',
#   'O3_8hr': '23',
#   'PM10': '13',
#   'PM2.5': '3',
#   'NO2': '4.5',
#   'NOx': '5.6',
#   'NO': '1.1',
#   'WindSpeed': '1',
#   'WindDirec': '249',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '11',
#   'SO2_AVG': '2',
#   'Longitude': '120.305689',
#   'Latitude': '22.757506',
#   'SiteId': '48'},
#  {'SiteName': '美濃',
#   'County': '高雄市',
#   'AQI': '29',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3',
#   'CO': '0.18',
#   'CO_8hr': '0.2',
#   'O3': '15',
#   'O3_8hr': '31',
#   'PM10': '16',
#   'PM2.5': '9',
#   'NO2': '7.2',
#   'NOx': '7.5',
#   'NO': '0.3',
#   'WindSpeed': '1.1',
#   'WindDirec': '50',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '8',
#   'PM10_AVG': '16',
#   'SO2_AVG': '2',
#   'Longitude': '120.530542',
#   'Latitude': '22.883583',
#   'SiteId': '47'},
#  {'SiteName': '臺南',
#   'County': '臺南市',
#   'AQI': '19',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.5',
#   'CO': '0.13',
#   'CO_8hr': '0.2',
#   'O3': '20',
#   'O3_8hr': '21',
#   'PM10': '7',
#   'PM2.5': '4',
#   'NO2': '2.2',
#   'NOx': '2.7',
#   'NO': '0.5',
#   'WindSpeed': '1.3',
#   'WindDirec': '203',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '8',
#   'SO2_AVG': '2',
#   'Longitude': '120.202617',
#   'Latitude': '22.984581',
#   'SiteId': '46'},
#  {'SiteName': '安南',
#   'County': '臺南市',
#   'AQI': '21',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.1',
#   'CO': '0.1',
#   'CO_8hr': '0.1',
#   'O3': '22',
#   'O3_8hr': '23',
#   'PM10': '11',
#   'PM2.5': '5',
#   'NO2': '4',
#   'NOx': '3.9',
#   'NO': '-0.1',
#   'WindSpeed': '1',
#   'WindDirec': '200',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '5',
#   'PM10_AVG': '15',
#   'SO2_AVG': '1',
#   'Longitude': '120.2175',
#   'Latitude': '23.048197',
#   'SiteId': '45'},
#  {'SiteName': '善化',
#   'County': '臺南市',
#   'AQI': '19',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.6',
#   'CO': '0.15',
#   'CO_8hr': '0.1',
#   'O3': '12',
#   'O3_8hr': '20',
#   'PM10': '8',
#   'PM2.5': '6',
#   'NO2': '11',
#   'NOx': '12',
#   'NO': '1.1',
#   'WindSpeed': '0.4',
#   'WindDirec': '173',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '10',
#   'SO2_AVG': '2',
#   'Longitude': '120.297142',
#   'Latitude': '23.115097',
#   'SiteId': '44'},
#  {'SiteName': '新營',
#   'County': '臺南市',
#   'AQI': '20',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.2',
#   'CO': '0.16',
#   'CO_8hr': '0.2',
#   'O3': '17',
#   'O3_8hr': '22',
#   'PM10': '12',
#   'PM2.5': '2',
#   'NO2': '8',
#   'NOx': '8.4',
#   'NO': '0.4',
#   'WindSpeed': '0.7',
#   'WindDirec': '205',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '11',
#   'SO2_AVG': '2',
#   'Longitude': '120.31725',
#   'Latitude': '23.305633',
#   'SiteId': '43'},
#  {'SiteName': '嘉義',
#   'County': '嘉義市',
#   'AQI': '22',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.3',
#   'CO': '0.16',
#   'CO_8hr': '0.2',
#   'O3': '17',
#   'O3_8hr': '24',
#   'PM10': '17',
#   'PM2.5': '5',
#   'NO2': '8',
#   'NOx': '9.2',
#   'NO': '1.2',
#   'WindSpeed': '1.4',
#   'WindDirec': '224',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '16',
#   'SO2_AVG': '1',
#   'Longitude': '120.440833',
#   'Latitude': '23.462778',
#   'SiteId': '42'},
#  {'SiteName': '臺西',
#   'County': '雲林縣',
#   'AQI': '24',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.1',
#   'CO': '0.14',
#   'CO_8hr': '0.1',
#   'O3': '17',
#   'O3_8hr': '26',
#   'PM10': '13',
#   'PM2.5': '6',
#   'NO2': '6.8',
#   'NOx': '7',
#   'NO': '0.2',
#   'WindSpeed': '1.8',
#   'WindDirec': '193',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '8',
#   'SO2_AVG': '3',
#   'Longitude': '120.202842',
#   'Latitude': '23.717533',
#   'SiteId': '41'},
#  {'SiteName': '朴子',
#   'County': '嘉義縣',
#   'AQI': '19',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.9',
#   'CO': '0.15',
#   'CO_8hr': '0.1',
#   'O3': '18',
#   'O3_8hr': '20',
#   'PM10': '15',
#   'PM2.5': '3',
#   'NO2': '4.4',
#   'NOx': '6.5',
#   'NO': '2.1',
#   'WindSpeed': '1.5',
#   'WindDirec': '245',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '4',
#   'PM10_AVG': '13',
#   'SO2_AVG': '2',
#   'Longitude': '120.24781',
#   'Latitude': '23.467123',
#   'SiteId': '40'},
#  {'SiteName': '新港',
#   'County': '嘉義縣',
#   'AQI': '22',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.4',
#   'CO': '0.14',
#   'CO_8hr': '0.1',
#   'O3': '14',
#   'O3_8hr': '22',
#   'PM10': '15',
#   'PM2.5': '8',
#   'NO2': '6.1',
#   'NOx': '7.3',
#   'NO': '1.2',
#   'WindSpeed': '1.8',
#   'WindDirec': '236',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '7',
#   'PM10_AVG': '20',
#   'SO2_AVG': '1',
#   'Longitude': '120.345531',
#   'Latitude': '23.554839',
#   'SiteId': '39'},
#  {'SiteName': '崙背',
#   'County': '雲林縣',
#   'AQI': '22',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3.6',
#   'CO': '0.16',
#   'CO_8hr': '0.1',
#   'O3': '16',
#   'O3_8hr': '24',
#   'PM10': '21',
#   'PM2.5': '9',
#   'NO2': '6.3',
#   'NOx': '7.9',
#   'NO': '1.5',
#   'WindSpeed': '1.2',
#   'WindDirec': '221',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '20',
#   'SO2_AVG': '3',
#   'Longitude': '120.348742',
#   'Latitude': '23.757547',
#   'SiteId': '38'},
#  {'SiteName': '斗六',
#   'County': '雲林縣',
#   'AQI': '31',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.1',
#   'CO': '0.23',
#   'CO_8hr': '0.2',
#   'O3': '12',
#   'O3_8hr': '29',
#   'PM10': '29',
#   'PM2.5': '13',
#   'NO2': '10',
#   'NOx': '12',
#   'NO': '1.6',
#   'WindSpeed': '1.7',
#   'WindDirec': '232',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '9',
#   'PM10_AVG': '23',
#   'SO2_AVG': '2',
#   'Longitude': '120.544994',
#   'Latitude': '23.711853',
#   'SiteId': '37'},
#  {'SiteName': '南投',
#   'County': '南投縣',
#   'AQI': '41',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.3',
#   'CO': '0.32',
#   'CO_8hr': '0.3',
#   'O3': '15',
#   'O3_8hr': '35',
#   'PM10': '27',
#   'PM2.5': '12',
#   'NO2': '14',
#   'NOx': '15',
#   'NO': '1.2',
#   'WindSpeed': '1.7',
#   'WindDirec': '161',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '13',
#   'PM10_AVG': '26',
#   'SO2_AVG': '2',
#   'Longitude': '120.685306',
#   'Latitude': '23.913',
#   'SiteId': '36'},
#  {'SiteName': '二林',
#   'County': '彰化縣',
#   'AQI': '37',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.3',
#   'CO': '0.16',
#   'CO_8hr': '0.1',
#   'O3': '16',
#   'O3_8hr': '26',
#   'PM10': '26',
#   'PM2.5': '12',
#   'NO2': '5.8',
#   'NOx': '7.2',
#   'NO': '1.3',
#   'WindSpeed': '1.8',
#   'WindDirec': '203',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '26',
#   'SO2_AVG': '3',
#   'Longitude': '120.409653',
#   'Latitude': '23.925175',
#   'SiteId': '35'},
#  {'SiteName': '線西',
#   'County': '彰化縣',
#   'AQI': '27',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3.1',
#   'CO': '0.12',
#   'CO_8hr': '0.1',
#   'O3': '24',
#   'O3_8hr': '29',
#   'PM10': '15',
#   'PM2.5': '4',
#   'NO2': '5.8',
#   'NOx': '6.6',
#   'NO': '0.8',
#   'WindSpeed': '1.6',
#   'WindDirec': '218',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '14',
#   'SO2_AVG': '2',
#   'Longitude': '120.469061',
#   'Latitude': '24.131672',
#   'SiteId': '34'},
#  {'SiteName': '彰化',
#   'County': '彰化縣',
#   'AQI': '27',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3.2',
#   'CO': '0.16',
#   'CO_8hr': '0.2',
#   'O3': '24',
#   'O3_8hr': '29',
#   'PM10': '18',
#   'PM2.5': '10',
#   'NO2': '5.3',
#   'NOx': '6.2',
#   'NO': '0.9',
#   'WindSpeed': '1.8',
#   'WindDirec': '221',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '8',
#   'PM10_AVG': '16',
#   'SO2_AVG': '4',
#   'Longitude': '120.541519',
#   'Latitude': '24.066',
#   'SiteId': '33'},
#  {'SiteName': '西屯',
#   'County': '臺中市',
#   'AQI': '29',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3.6',
#   'CO': '0.17',
#   'CO_8hr': '0.2',
#   'O3': '22',
#   'O3_8hr': '30',
#   'PM10': '15',
#   'PM2.5': '7',
#   'NO2': '8.2',
#   'NOx': '8.8',
#   'NO': '0.6',
#   'WindSpeed': '1.5',
#   'WindDirec': '222',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '9',
#   'PM10_AVG': '20',
#   'SO2_AVG': '3',
#   'Longitude': '120.616917',
#   'Latitude': '24.162197',
#   'SiteId': '32'},
#  {'SiteName': '忠明',
#   'County': '臺中市',
#   'AQI': '31',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.6',
#   'CO': '0.24',
#   'CO_8hr': '0.2',
#   'O3': '17',
#   'O3_8hr': '26',
#   'PM10': '17',
#   'PM2.5': '10',
#   'NO2': '12',
#   'NOx': '14',
#   'NO': '2.2',
#   'WindSpeed': '1.1',
#   'WindDirec': '217',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '10',
#   'PM10_AVG': '19',
#   'SO2_AVG': '3',
#   'Longitude': '120.641092',
#   'Latitude': '24.151958',
#   'SiteId': '31'},
#  {'SiteName': '大里',
#   'County': '臺中市',
#   'AQI': '39',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3.3',
#   'CO': '0.26',
#   'CO_8hr': '0.3',
#   'O3': '15',
#   'O3_8hr': '30',
#   'PM10': '24',
#   'PM2.5': '14',
#   'NO2': '12',
#   'NOx': '14',
#   'NO': '1.9',
#   'WindSpeed': '1.9',
#   'WindDirec': '270',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '25',
#   'SO2_AVG': '4',
#   'Longitude': '120.677689',
#   'Latitude': '24.099611',
#   'SiteId': '30'},
#  {'SiteName': '沙鹿',
#   'County': '臺中市',
#   'AQI': '22',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3',
#   'CO': '0.12',
#   'CO_8hr': '0.1',
#   'O3': '22',
#   'O3_8hr': '24',
#   'PM10': '14',
#   'PM2.5': '5',
#   'NO2': '8',
#   'NOx': '8.6',
#   'NO': '0.5',
#   'WindSpeed': '1.3',
#   'WindDirec': '212',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '13',
#   'SO2_AVG': '3',
#   'Longitude': '120.568794',
#   'Latitude': '24.225628',
#   'SiteId': '29'},
#  {'SiteName': '豐原',
#   'County': '臺中市',
#   'AQI': '32',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3.1',
#   'CO': '0.38',
#   'CO_8hr': '0.3',
#   'O3': '5.9',
#   'O3_8hr': '24',
#   'PM10': '22',
#   'PM2.5': '8',
#   'NO2': '17',
#   'NOx': '17',
#   'NO': '0.5',
#   'WindSpeed': '1.8',
#   'WindDirec': '121',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '10',
#   'PM10_AVG': '25',
#   'SO2_AVG': '3',
#   'Longitude': '120.741711',
#   'Latitude': '24.256586',
#   'SiteId': '28'},
#  {'SiteName': '三義',
#   'County': '苗栗縣',
#   'AQI': '27',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.3',
#   'CO': '0.22',
#   'CO_8hr': '0.2',
#   'O3': '7.5',
#   'O3_8hr': '21',
#   'PM10': '27',
#   'PM2.5': '13',
#   'NO2': '12',
#   'NOx': '14',
#   'NO': '1.7',
#   'WindSpeed': '1.1',
#   'WindDirec': '192',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '8',
#   'PM10_AVG': '20',
#   'SO2_AVG': '2',
#   'Longitude': '120.758833',
#   'Latitude': '24.382942',
#   'SiteId': '27'},
#  {'SiteName': '苗栗',
#   'County': '苗栗縣',
#   'AQI': '30',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.8',
#   'CO': '0.18',
#   'CO_8hr': '0.2',
#   'O3': '14',
#   'O3_8hr': '21',
#   'PM10': '16',
#   'PM2.5': '12',
#   'NO2': '9',
#   'NOx': '11',
#   'NO': '2.1',
#   'WindSpeed': '0.8',
#   'WindDirec': '212',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '9',
#   'PM10_AVG': '18',
#   'SO2_AVG': '3',
#   'Longitude': '120.8202',
#   'Latitude': '24.565269',
#   'SiteId': '26'},
#  {'SiteName': '頭份',
#   'County': '苗栗縣',
#   'AQI': '47',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.4',
#   'CO': '0.27',
#   'CO_8hr': '0.2',
#   'O3': '15',
#   'O3_8hr': '20',
#   'PM10': '31',
#   'PM2.5': '25',
#   'NO2': '11',
#   'NOx': '12',
#   'NO': '0.7',
#   'WindSpeed': '1.4',
#   'WindDirec': '265',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '14',
#   'PM10_AVG': '21',
#   'SO2_AVG': '3',
#   'Longitude': '120.898572',
#   'Latitude': '24.696969',
#   'SiteId': '25'},
#  {'SiteName': '新竹',
#   'County': '新竹市',
#   'AQI': '26',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.3',
#   'CO': '0.19',
#   'CO_8hr': '0.2',
#   'O3': '21',
#   'O3_8hr': '23',
#   'PM10': '7',
#   'PM2.5': '6',
#   'NO2': '7.4',
#   'NOx': '8.5',
#   'NO': '1',
#   'WindSpeed': '1.2',
#   'WindDirec': '270',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '8',
#   'PM10_AVG': '14',
#   'SO2_AVG': '3',
#   'Longitude': '120.972075',
#   'Latitude': '24.805619',
#   'SiteId': '24'},
#  {'SiteName': '竹東',
#   'County': '新竹縣',
#   'AQI': '45',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.3',
#   'CO': '0.21',
#   'CO_8hr': '0.2',
#   'O3': '23',
#   'O3_8hr': '37',
#   'PM10': '23',
#   'PM2.5': '14',
#   'NO2': '7.8',
#   'NOx': '8.8',
#   'NO': '1',
#   'WindSpeed': '0.5',
#   'WindDirec': '111',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '14',
#   'PM10_AVG': '24',
#   'SO2_AVG': '2',
#   'Longitude': '121.088903',
#   'Latitude': '24.740644',
#   'SiteId': '23'},
#  {'SiteName': '湖口',
#   'County': '新竹縣',
#   'AQI': '24',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.4',
#   'CO': '0.17',
#   'CO_8hr': '0.1',
#   'O3': '19',
#   'O3_8hr': '26',
#   'PM10': '12',
#   'PM2.5': '7',
#   'NO2': '7.7',
#   'NOx': '9.4',
#   'NO': '1.7',
#   'WindSpeed': '1.2',
#   'WindDirec': '261',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '7',
#   'PM10_AVG': '13',
#   'SO2_AVG': '3',
#   'Longitude': '121.038653',
#   'Latitude': '24.900142',
#   'SiteId': '22'},
#  {'SiteName': '龍潭',
#   'County': '桃園市',
#   'AQI': '45',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3.6',
#   'CO': '0.36',
#   'CO_8hr': '0.3',
#   'O3': '8.5',
#   'O3_8hr': '40',
#   'PM10': '28',
#   'PM2.5': '18',
#   'NO2': '25',
#   'NOx': '29',
#   'NO': '4.3',
#   'WindSpeed': '1.6',
#   'WindDirec': '118',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '14',
#   'PM10_AVG': '23',
#   'SO2_AVG': '2',
#   'Longitude': '121.21635',
#   'Latitude': '24.863869',
#   'SiteId': '21'},
#  {'SiteName': '平鎮',
#   'County': '桃園市',
#   'AQI': '38',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '3.5',
#   'CO': '0.3',
#   'CO_8hr': '0.2',
#   'O3': '7.3',
#   'O3_8hr': '26',
#   'PM10': '20',
#   'PM2.5': '10',
#   'NO2': '21',
#   'NOx': '25',
#   'NO': '3.8',
#   'WindSpeed': '1.1',
#   'WindDirec': '18',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '29',
#   'SO2_AVG': '3',
#   'Longitude': '121.203986',
#   'Latitude': '24.952786',
#   'SiteId': '20'},
#  {'SiteName': '觀音',
#   'County': '桃園市',
#   'AQI': '21',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '0.8',
#   'CO': '0.1',
#   'CO_8hr': '0.1',
#   'O3': '20',
#   'O3_8hr': '23',
#   'PM10': '15',
#   'PM2.5': '6',
#   'NO2': '5.8',
#   'NOx': '5.4',
#   'NO': '-0.3',
#   'WindSpeed': '0.9',
#   'WindDirec': '241',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '6',
#   'PM10_AVG': '14',
#   'SO2_AVG': '1',
#   'Longitude': '121.082761',
#   'Latitude': '25.035503',
#   'SiteId': '19'},
#  {'SiteName': '大園',
#   'County': '桃園市',
#   'AQI': '28',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.9',
#   'CO': '0.18',
#   'CO_8hr': '0.2',
#   'O3': '17',
#   'O3_8hr': '30',
#   'PM10': '23',
#   'PM2.5': '7',
#   'NO2': '11',
#   'NOx': '11',
#   'NO': '0.5',
#   'WindSpeed': '1',
#   'WindDirec': '230',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '7',
#   'PM10_AVG': '19',
#   'SO2_AVG': '3',
#   'Longitude': '121.201811',
#   'Latitude': '25.060344',
#   'SiteId': '18'},
#  {'SiteName': '桃園',
#   'County': '桃園市',
#   'AQI': '36',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '7',
#   'CO': '0.39',
#   'CO_8hr': '0.3',
#   'O3': '6.3',
#   'O3_8hr': '24',
#   'PM10': '16',
#   'PM2.5': '10',
#   'NO2': '24',
#   'NOx': '25',
#   'NO': '1.2',
#   'WindSpeed': '0.7',
#   'WindDirec': '252',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '11',
#   'PM10_AVG': '21',
#   'SO2_AVG': '4',
#   'Longitude': '121.304383',
#   'Latitude': '24.995368',
#   'SiteId': '17'},
#  {'SiteName': '大同',
#   'County': '臺北市',
#   'AQI': '38',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.8',
#   'CO': '1.35',
#   'CO_8hr': '1.1',
#   'O3': '-',
#   'O3_8hr': '',
#   'PM10': '19',
#   'PM2.5': '8',
#   'NO2': '30',
#   'NOx': '81',
#   'NO': '51',
#   'WindSpeed': '',
#   'WindDirec': '',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '25',
#   'SO2_AVG': '3',
#   'Longitude': '121.513311',
#   'Latitude': '25.0632',
#   'SiteId': '16'},
#  {'SiteName': '松山',
#   'County': '臺北市',
#   'AQI': '37',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.9',
#   'CO': '0.3',
#   'CO_8hr': '0.3',
#   'O3': '13',
#   'O3_8hr': '33',
#   'PM10': '17',
#   'PM2.5': '7',
#   'NO2': '16',
#   'NOx': '22',
#   'NO': '6.3',
#   'WindSpeed': '1.6',
#   'WindDirec': '67',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '11',
#   'PM10_AVG': '21',
#   'SO2_AVG': '3',
#   'Longitude': '121.578611',
#   'Latitude': '25.05',
#   'SiteId': '15'},
#  {'SiteName': '古亭',
#   'County': '臺北市',
#   'AQI': '45',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.5',
#   'CO': '0.32',
#   'CO_8hr': '0.4',
#   'O3': '11',
#   'O3_8hr': '49',
#   'PM10': '18',
#   'PM2.5': '8',
#   'NO2': '16',
#   'NOx': '18',
#   'NO': '1.9',
#   'WindSpeed': '1.4',
#   'WindDirec': '221',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '20',
#   'SO2_AVG': '2',
#   'Longitude': '121.529556',
#   'Latitude': '25.020608',
#   'SiteId': '14'},
#  {'SiteName': '萬華',
#   'County': '臺北市',
#   'AQI': '40',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.6',
#   'CO': '0.44',
#   'CO_8hr': '0.5',
#   'O3': '5.1',
#   'O3_8hr': '30',
#   'PM10': '20',
#   'PM2.5': '9',
#   'NO2': '22',
#   'NOx': '32',
#   'NO': '11',
#   'WindSpeed': '1.8',
#   'WindDirec': '163',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '12',
#   'PM10_AVG': '25',
#   'SO2_AVG': '2',
#   'Longitude': '121.507972',
#   'Latitude': '25.046503',
#   'SiteId': '13'},
#  {'SiteName': '中山',
#   'County': '臺北市',
#   'AQI': '34',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '6',
#   'CO': '0.44',
#   'CO_8hr': '0.6',
#   'O3': '12',
#   'O3_8hr': '37',
#   'PM10': '16',
#   'PM2.5': '8',
#   'NO2': '21',
#   'NOx': '27',
#   'NO': '5.6',
#   'WindSpeed': '1.6',
#   'WindDirec': '142',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '8',
#   'PM10_AVG': '23',
#   'SO2_AVG': '3',
#   'Longitude': '121.526528',
#   'Latitude': '25.062361',
#   'SiteId': '12'},
#  {'SiteName': '士林',
#   'County': '臺北市',
#   'AQI': '43',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.7',
#   'CO': '0.32',
#   'CO_8hr': '0.3',
#   'O3': '16',
#   'O3_8hr': '41',
#   'PM10': '15',
#   'PM2.5': '11',
#   'NO2': '16',
#   'NOx': '18',
#   'NO': '2.4',
#   'WindSpeed': '1.6',
#   'WindDirec': '104',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '13',
#   'PM10_AVG': '25',
#   'SO2_AVG': '3',
#   'Longitude': '121.515389',
#   'Latitude': '25.105417',
#   'SiteId': '11'},
#  {'SiteName': '淡水',
#   'County': '新北市',
#   'AQI': '42',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.4',
#   'CO': '0.44',
#   'CO_8hr': '0.2',
#   'O3': '13',
#   'O3_8hr': '35',
#   'PM10': '25',
#   'PM2.5': '14',
#   'NO2': '16',
#   'NOx': '17',
#   'NO': '0.7',
#   'WindSpeed': '',
#   'WindDirec': '',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '13',
#   'PM10_AVG': '18',
#   'SO2_AVG': '2',
#   'Longitude': '121.449239',
#   'Latitude': '25.1645',
#   'SiteId': '10'},
#  {'SiteName': '林口',
#   'County': '新北市',
#   'AQI': '31',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2',
#   'CO': '',
#   'CO_8hr': '',
#   'O3': '8.9',
#   'O3_8hr': '33',
#   'PM10': '19',
#   'PM2.5': '10',
#   'NO2': '24',
#   'NOx': '26',
#   'NO': '2.1',
#   'WindSpeed': '1.3',
#   'WindDirec': '137',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '9',
#   'PM10_AVG': '19',
#   'SO2_AVG': '3',
#   'Longitude': '121.376869',
#   'Latitude': '25.077197',
#   'SiteId': '9'},
#  {'SiteName': '菜寮',
#   'County': '新北市',
#   'AQI': '36',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.4',
#   'CO': '0.61',
#   'CO_8hr': '0.4',
#   'O3': '4.4',
#   'O3_8hr': '28',
#   'PM10': '21',
#   'PM2.5': '9',
#   'NO2': '27',
#   'NOx': '31',
#   'NO': '3.9',
#   'WindSpeed': '1.6',
#   'WindDirec': '202',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '11',
#   'PM10_AVG': '23',
#   'SO2_AVG': '3',
#   'Longitude': '121.481028',
#   'Latitude': '25.06895',
#   'SiteId': '8'},
#  {'SiteName': '新莊',
#   'County': '新北市',
#   'AQI': '43',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2',
#   'CO': '0.59',
#   'CO_8hr': '0.3',
#   'O3': '2.5',
#   'O3_8hr': '30',
#   'PM10': '23',
#   'PM2.5': '12',
#   'NO2': '32',
#   'NOx': '43',
#   'NO': '11',
#   'WindSpeed': '0.7',
#   'WindDirec': '62',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '13',
#   'PM10_AVG': '30',
#   'SO2_AVG': '3',
#   'Longitude': '121.4325',
#   'Latitude': '25.037972',
#   'SiteId': '7'},
#  {'SiteName': '板橋',
#   'County': '新北市',
#   'AQI': '34',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2',
#   'CO': '0.42',
#   'CO_8hr': '0.5',
#   'O3': '11',
#   'O3_8hr': '21',
#   'PM10': '17',
#   'PM2.5': '8',
#   'NO2': '20',
#   'NOx': '25',
#   'NO': '5.1',
#   'WindSpeed': '2.1',
#   'WindDirec': '133',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '11',
#   'PM10_AVG': '23',
#   'SO2_AVG': '4',
#   'Longitude': '121.458667',
#   'Latitude': '25.012972',
#   'SiteId': '6'},
#  {'SiteName': '土城',
#   'County': '新北市',
#   'AQI': '43',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.2',
#   'CO': '0.42',
#   'CO_8hr': '0.4',
#   'O3': '7',
#   'O3_8hr': '46',
#   'PM10': '25',
#   'PM2.5': '8',
#   'NO2': '22',
#   'NOx': '28',
#   'NO': '5.5',
#   'WindSpeed': '1.9',
#   'WindDirec': '158',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '13',
#   'PM10_AVG': '28',
#   'SO2_AVG': '3',
#   'Longitude': '121.451861',
#   'Latitude': '24.982528',
#   'SiteId': '5'},
#  {'SiteName': '新店',
#   'County': '新北市',
#   'AQI': '30',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.6',
#   'CO': '0.24',
#   'CO_8hr': '0.3',
#   'O3': '15',
#   'O3_8hr': '32',
#   'PM10': '14',
#   'PM2.5': '4',
#   'NO2': '9.7',
#   'NOx': '12',
#   'NO': '2.5',
#   'WindSpeed': '2.6',
#   'WindDirec': '184',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '8',
#   'PM10_AVG': '16',
#   'SO2_AVG': '2',
#   'Longitude': '121.537778',
#   'Latitude': '24.977222',
#   'SiteId': '4'},
#  {'SiteName': '萬里',
#   'County': '新北市',
#   'AQI': '36',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2.2',
#   'CO': '0.14',
#   'CO_8hr': '0.2',
#   'O3': '20',
#   'O3_8hr': '32',
#   'PM10': '17',
#   'PM2.5': '12',
#   'NO2': '6.6',
#   'NOx': '7.2',
#   'NO': '0.6',
#   'WindSpeed': '3.4',
#   'WindDirec': '212',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '11',
#   'PM10_AVG': '18',
#   'SO2_AVG': '3',
#   'Longitude': '121.689881',
#   'Latitude': '25.179667',
#   'SiteId': '3'},
#  {'SiteName': '汐止',
#   'County': '新北市',
#   'AQI': '42',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '1.8',
#   'CO': '0.28',
#   'CO_8hr': '0.2',
#   'O3': '7.5',
#   'O3_8hr': '29',
#   'PM10': '17',
#   'PM2.5': '14',
#   'NO2': '19',
#   'NOx': '23',
#   'NO': '4.2',
#   'WindSpeed': '1.1',
#   'WindDirec': '34',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '13',
#   'PM10_AVG': '21',
#   'SO2_AVG': '2',
#   'Longitude': '121.6423',
#   'Latitude': '25.067131',
#   'SiteId': '2'},
#  {'SiteName': '基隆',
#   'County': '基隆市',
#   'AQI': '29',
#   'Pollutant': '',
#   'Status': '良好',
#   'SO2': '2',
#   'CO': '0.38',
#   'CO_8hr': '0.2',
#   'O3': '5.4',
#   'O3_8hr': '15',
#   'PM10': '20',
#   'PM2.5': '10',
#   'NO2': '15',
#   'NOx': '20',
#   'NO': '4.4',
#   'WindSpeed': '1',
#   'WindDirec': '268',
#   'PublishTime': '2020-07-13 22:00',
#   'PM2.5_AVG': '9',
#   'PM10_AVG': '20',
#   'SO2_AVG': '2',
#   'Longitude': '121.760056',
#   'Latitude': '25.129167',
#   'SiteId': '1'}]
