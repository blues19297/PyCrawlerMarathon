# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 取出今天所有的發文
# * ② 如果想要依照類別分類，怎麼儲存會比較好？
# * ③ 哪一個類別的文章最多

# %% [markdown]
# ### ① 取出今天所有的發文

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.ettoday.net/news/news-list.htm'
r = requests.get(url)
soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find(class_="part_list_2").find_all('h3'):
    print(d.find(class_='date').text, d.find_all('a')[-1].text)
# Out:
# 2020/07/21 23:47 鄭雨盛變總統擔心「我這麼帥可以嗎？」　男神帥臉征服柳演錫
# 2020/07/21 23:47 徐佳瑩開唱！台南夏日音樂節將軍吼8/15登場　套裝遊程機＋酒偽出國
# 2020/07/21 23:27 可變重慶小麵或日式拉麵　詹麵新口味「蔥油雞汁麵」有無限發揮空間
# 2020/07/21 23:23 疫情失控！「全球一天內死了7,630人」王浩宇酸：台灣人卻還在吵塑膠套
# 2020/07/21 23:17 老闆反擊「要戰我陪妳」！　批Yamy不擇手段做事：發音檔給妳的人瑟瑟發抖
# 2020/07/21 23:10 滅火器金曲剛入圍五大獎　將率七組藝人「報復性下午唱到晚上」！
# 2020/07/21 23:10 米克斯化身「大小孩」貼肚討摸　攬牢牢融化網：你是牠的全世界
# 2020/07/21 23:06 鄧紫棋「邊飆高音+邊練核心」　健身房清唱《來自天堂的魔鬼》穩到爆
# 2020/07/21 23:06 藝FUN券沒抽中？　網互相取暖：我們生來要得威力彩
# 2020/07/21 23:05 總統府「電梯上上下下」傳鬧鬼！北市府回應了　4點反擊打臉
# 2020/07/21 23:01 油煙致肺癌危機　國衛院研究：下廚用抽油煙機「最多可降63%罹癌風險」
# 2020/07/21 22:56 大陸發布新規定　登機前5天內需做好核酸檢測
# 2020/07/21 22:55 特戰女兵「辣照外流」被改成長輩圖　國防部回應了
# 2020/07/21 22:48 安瑪莉超模POSE下秒露「雙層游泳圈」　搞笑曝真實身材藏含義：為自己驕傲！
# 2020/07/21 22:46 歐盟振興基金定案！援助西班牙4.7兆元　只要還一半
# 2020/07/21 22:45 快訊／大樂透1.3億、今彩539頭獎一注獨得　全開在桃園蘆竹
# 2020/07/21 22:41 如果歐盟也封殺華為　《華爾街日報》：中國將禁止愛立信、諾基亞產品出口
# 2020/07/21 22:37 陸商務部將阻止愛立信、諾基亞出口？汪文斌批：惡意捏造的假新聞
# 2020/07/21 22:35 全中運／阻擋丁華恬二連霸　賴品儒摘金扳回一城
# 2020/07/21 22:34 屋內傳熱情叫聲暖迎！　她見失足狗「浴缸內吶喊」心涼：天兵欸
# ...

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
print("[生活]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_lifestyle"):
        str += d.find_all('a')[-1].text
print(str)

print("[時尚]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_fashion"):
        str += d.find_all('a')[-1].text
print(str)

print("[影劇]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_star"):
        str += d.find_all('a')[-1].text
print(str)

print("[社會]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_society"):
        str += d.find_all('a')[-1].text
print(str)


print("[健康]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_health"):
        str += d.find_all('a')[-1].text
print(str)


print("[體育]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_sport"):
        str += d.find_all('a')[-1].text
print(str)


print("[寵物動物]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_pet"):
        str += d.find_all('a')[-1].text
print(str)


print("[財經]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_finance"):
        str += d.find_all('a')[-1].text
print(str)


print("[保險]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_insurance"):
        str += d.find_all('a')[-1].text
print(str)


print("[地方]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_local"):
        str += d.find_all('a')[-1].text
print(str)


print("[國際]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_global"):
        str += d.find_all('a')[-1].text
print(str)


print("[旅遊]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_travel"):
        str += d.find_all('a')[-1].text
print(str)


print("[軍武]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_army"):
        str += d.find_all('a')[-1].text
print(str)


print("[政治]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_news"):
        str += d.find_all('a')[-1].text
print(str)


print("[房產雲]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_house"):
        str += d.find_all('a')[-1].text
print(str)


print("[大陸]")
str = ""
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_china"):
        str += d.find_all('a')[-1].text
print(str)
# Out:
# [生活]
# 藝FUN券沒抽中？　網互相取暖：我們生來要得威力彩嘴巴破洞怎麼治療？天然水果就有效　網曝1關鍵：隔天就好了台南「7年輕男女」保時捷停門口　她竟開門丟2坨就走！老闆氣瘋公布長相7/25竹北新月沙灘海洋音樂嘉年華　畢書盡、八三夭超強卡司嗨翻整場高雄男嗜「菸酒檳」30年不離口！臉上長出巨大「巧克力菠蘿麵包」紗布包緊緊不敢出門調皮兒把iPhone8放冷凍庫整晚變冰棒！　網笑翻：微波解凍金門牧場發現4頭牛疑患牛結節疹　23日起全縣施打疫苗別白費力氣了！盤點「普妹撩不動」的星座男Top3　怪奇水瓶超難搞快訊／藝FUN券中獎「無法驗證」　文化部道歉了影／桃園出現今年首例本土性登革熱患者　鄭文燦：23日起全市大消毒250歲生日快樂！　7/25嘉義青年管弦樂團重現貝多芬名曲個人健康飲食、循環經濟當道　植物肉、低鉀蔬菜市場將加速成長
# [時尚]
# 這樣看電影太享受！桃園首間「新光影城」5大特色　無印自動販賣機也有跟著買不出錯！2020上半年度「唇膏銷售冠軍」揭曉天氣太熱火氣也跟著來！翻張牌告訴妳最近一直被誰惹火減肥亂節食小心大落髮！5招日常養護小秘訣改善＋預防掉髮「四千年一遇美女」鞠婧祎撞衫秦嵐！閃片裙尬仙氣…網：這細節她完勝
# [影劇]
# ...

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_lifestyle"): 
        count += 1
print('生活出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_fashion"): 
        count += 1
print('時尚出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_star"): 
        count += 1
print('影劇出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_society"): 
        count += 1
print('社會出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_health"): 
        count += 1
print('健康出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_sport"): 
        count += 1
print('體育出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_pet"): 
        count += 1
print('寵物動物出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_finance"): 
        count += 1
print('財經出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_insurance"): 
        count += 1
print('保險出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_local"): 
        count += 1
print('地方出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_global"): 
        count += 1
print('國際出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_travel"): 
        count += 1
print('旅遊出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_army"): 
        count += 1
print('軍武出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_news"): 
        count += 1
print('政治出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_house"): 
        count += 1
print('房產雲出現%d次'%(count))
count = 0
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="tag c_china"): 
        count += 1
print('大陸出現%d次'%(count))

print('==========影劇類文章出現最多次=========')
# Out:
# 生活出現12次
# 時尚出現5次
# 影劇出現18次
# 社會出現9次
# 健康出現6次
# 體育出現9次
# 寵物動物出現4次
# 財經出現10次
# 保險出現1次
# 地方出現5次
# 國際出現6次
# 旅遊出現4次
# 軍武出現1次
# 政治出現7次
# 房產雲出現1次
# 大陸出現2次
# ==========影劇類文章出現最多次=========
